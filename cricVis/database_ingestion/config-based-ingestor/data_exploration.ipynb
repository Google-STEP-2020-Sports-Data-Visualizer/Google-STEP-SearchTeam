# %% [markdown]
# # Data Exploration
#
# In this notebook, the data and the columns in the dataset is examined before deciding on the config settings for cleaning the data and creating the database.

# %%
import pandas as pd

# %%
df = pd.read_csv("csv_files/cricket_data.csv")

for (col, col_type) in zip(df.dtypes.index, df.dtypes):
    print("{col}: {col_type}".format(col=col, col_type=col_type))
# Out:
# ID: int64
# NAME: object
# COUNTRY: object
# Full name: object
# Born: object
# Died: object
# Current age: object
# Major teams: object
# Education: object
# Height: object
# Nickname: float64
# Playing role: object
# Batting style: object
# Bowling style: object
# Other: object
# Relation: object
# In a nutshell: object
# DESCRIPTION: object
# AWARDS: object
# BATTING_Tests_Mat: float64
# BATTING_Tests_Inns: object
# BATTING_Tests_NO: object
# BATTING_Tests_Runs: object
# BATTING_Tests_HS: object
# BATTING_Tests_Ave: object
# BATTING_Tests_BF: object
# BATTING_Tests_SR: object
# BATTING_Tests_100: object
# BATTING_Tests_50: object
# BATTING_Tests_4s: object
# BATTING_Tests_6s: object
# BATTING_Tests_Ct: object
# BATTING_Tests_St: object
# BATTING_ODIs_Mat: float64
# BATTING_ODIs_Inns: object
# BATTING_ODIs_NO: object
# BATTING_ODIs_Runs: object
# BATTING_ODIs_HS: object
# BATTING_ODIs_Ave: object
# BATTING_ODIs_BF: object
# BATTING_ODIs_SR: object
# BATTING_ODIs_100: object
# BATTING_ODIs_50: object
# BATTING_ODIs_4s: object
# BATTING_ODIs_6s: object
# BATTING_ODIs_Ct: object
# BATTING_ODIs_St: object
# BATTING_T20Is_Mat: float64
# BATTING_T20Is_Inns: object
# BATTING_T20Is_NO: object
# BATTING_T20Is_Runs: object
# BATTING_T20Is_HS: object
# BATTING_T20Is_Ave: object
# BATTING_T20Is_BF: object
# BATTING_T20Is_SR: object
# BATTING_T20Is_100: object
# BATTING_T20Is_50: object
# BATTING_T20Is_4s: object
# BATTING_T20Is_6s: object
# BATTING_T20Is_Ct: object
# BATTING_T20Is_St: object
# BATTING_First-class_Mat: float64
# BATTING_First-class_Inns: object
# BATTING_First-class_NO: object
# BATTING_First-class_Runs: object
# BATTING_First-class_HS: object
# BATTING_First-class_Ave: object
# BATTING_First-class_BF: object
# BATTING_First-class_SR: object
# BATTING_First-class_100: object
# BATTING_First-class_50: object
# BATTING_First-class_4s: object
# BATTING_First-class_6s: object
# BATTING_First-class_Ct: object
# BATTING_First-class_St: object
# BATTING_List A_Mat: float64
# BATTING_List A_Inns: object
# BATTING_List A_NO: object
# BATTING_List A_Runs: object
# BATTING_List A_HS: object
# BATTING_List A_Ave: object
# BATTING_List A_BF: object
# BATTING_List A_SR: object
# BATTING_List A_100: object
# BATTING_List A_50: object
# BATTING_List A_4s: object
# BATTING_List A_6s: object
# BATTING_List A_Ct: object
# BATTING_List A_St: object
# BATTING_T20s_Mat: float64
# BATTING_T20s_Inns: object
# BATTING_T20s_NO: object
# BATTING_T20s_Runs: object
# BATTING_T20s_HS: object
# BATTING_T20s_Ave: object
# BATTING_T20s_BF: object
# BATTING_T20s_SR: object
# BATTING_T20s_100: object
# BATTING_T20s_50: object
# BATTING_T20s_4s: object
# BATTING_T20s_6s: object
# BATTING_T20s_Ct: object
# BATTING_T20s_St: object
# BOWLING_Tests_Mat: float64
# BOWLING_Tests_Inns: object
# BOWLING_Tests_Balls: object
# BOWLING_Tests_Runs: object
# BOWLING_Tests_Wkts: object
# BOWLING_Tests_BBI: object
# BOWLING_Tests_BBM: object
# BOWLING_Tests_Ave: object
# BOWLING_Tests_Econ: object
# BOWLING_Tests_SR: object
# BOWLING_Tests_4w: object
# BOWLING_Tests_5w: object
# BOWLING_Tests_10: object
# BOWLING_ODIs_Mat: float64
# BOWLING_ODIs_Inns: object
# BOWLING_ODIs_Balls: object
# BOWLING_ODIs_Runs: object
# BOWLING_ODIs_Wkts: object
# BOWLING_ODIs_BBI: object
# BOWLING_ODIs_BBM: object
# BOWLING_ODIs_Ave: object
# BOWLING_ODIs_Econ: object
# BOWLING_ODIs_SR: object
# BOWLING_ODIs_4w: object
# BOWLING_ODIs_5w: object
# BOWLING_ODIs_10: object
# BOWLING_T20Is_Mat: float64
# BOWLING_T20Is_Inns: object
# BOWLING_T20Is_Balls: object
# BOWLING_T20Is_Runs: object
# BOWLING_T20Is_Wkts: object
# BOWLING_T20Is_BBI: object
# BOWLING_T20Is_BBM: object
# BOWLING_T20Is_Ave: object
# BOWLING_T20Is_Econ: object
# BOWLING_T20Is_SR: object
# BOWLING_T20Is_4w: object
# BOWLING_T20Is_5w: object
# BOWLING_T20Is_10: object
# BOWLING_First-class_Mat: float64
# BOWLING_First-class_Inns: object
# BOWLING_First-class_Balls: object
# BOWLING_First-class_Runs: object
# BOWLING_First-class_Wkts: object
# BOWLING_First-class_BBI: object
# BOWLING_First-class_BBM: object
# BOWLING_First-class_Ave: object
# BOWLING_First-class_Econ: object
# BOWLING_First-class_SR: object
# BOWLING_First-class_4w: object
# BOWLING_First-class_5w: object
# BOWLING_First-class_10: object
# BOWLING_List A_Mat: float64
# BOWLING_List A_Inns: object
# BOWLING_List A_Balls: object
# BOWLING_List A_Runs: object
# BOWLING_List A_Wkts: object
# BOWLING_List A_BBI: object
# BOWLING_List A_BBM: object
# BOWLING_List A_Ave: object
# BOWLING_List A_Econ: object
# BOWLING_List A_SR: object
# BOWLING_List A_4w: object
# BOWLING_List A_5w: object
# BOWLING_List A_10: object
# BOWLING_T20s_Mat: float64
# BOWLING_T20s_Inns: object
# BOWLING_T20s_Balls: object
# BOWLING_T20s_Runs: object
# BOWLING_T20s_Wkts: object
# BOWLING_T20s_BBI: object
# BOWLING_T20s_BBM: object
# BOWLING_T20s_Ave: object
# BOWLING_T20s_Econ: object
# BOWLING_T20s_SR: object
# BOWLING_T20s_4w: object
# BOWLING_T20s_5w: object
# BOWLING_T20s_10: object

# %%
# Names of required columns and their types
column_types = {"ID": "int64",
"NAME": "object",
"Born": "object",
"Died": "object",
"Major teams": "object",
"Playing role": "object",
"Batting style": "object",
"Bowling style": "object",
"BATTING_Tests_Runs": "float64",
"BATTING_Tests_BF": "float64",
"BATTING_Tests_SR": "float64",
"BATTING_Tests_100": "float64",
"BATTING_Tests_50": "float64",
"BATTING_Tests_4s": "float64",
"BATTING_Tests_6s": "float64",
"BATTING_ODIs_Runs": "float64",
"BATTING_ODIs_BF": "float64",
"BATTING_ODIs_SR": "float64",
"BATTING_ODIs_100": "float64",
"BATTING_ODIs_50": "float64",
"BATTING_ODIs_4s": "float64",
"BATTING_ODIs_6s": "float64",
"BATTING_T20Is_Runs": "float64",
"BATTING_T20Is_BF": "float64",
"BATTING_T20Is_SR": "float64",
"BATTING_T20Is_100": "float64",
"BATTING_T20Is_50": "float64",
"BATTING_T20Is_4s": "float64",
"BATTING_T20Is_6s": "float64",
"BOWLING_Tests_Balls": "float64",
"BOWLING_Tests_Runs": "float64",
"BOWLING_Tests_Wkts": "float64",
"BOWLING_Tests_Econ": "float64",
"BOWLING_ODIs_Balls": "float64",
"BOWLING_ODIs_Runs": "float64",
"BOWLING_ODIs_Wkts": "float64",
"BOWLING_ODIs_Econ": "float64",
"BOWLING_T20Is_Balls": "float64",
"BOWLING_T20Is_Runs": "float64",
"BOWLING_T20Is_Wkts": "float64",
"BOWLING_T20Is_Econ": "float64"}

# %%
df = pd.read_csv("csv_files/cricket_data.csv", 
                 usecols=list(column_types.keys()), 
                 dtype=column_types,
                 na_values=['-', 'NA'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# TypeError: Cannot cast array from dtype('O') to dtype('float64') according to the rule 'safe'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-4158c85dab8b> in <module>
#       2                  usecols=list(column_types.keys()),
#       3                  dtype=column_types,
# ----> 4                  na_values=['-', 'NA'])
#
# ~/.local/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~/.local/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     try:
# --> 454         data = parser.read(nrows)
#     455     finally:
#     456         parser.close()
#
# ~/.local/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1131     def read(self, nrows=None):
#    1132         nrows = _validate_integer("nrows", nrows)
# -> 1133         ret = self._engine.read(nrows)
#    1134
#    1135         # May alter columns / col_dict
#
# ~/.local/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2035     def read(self, nrows=None):
#    2036         try:
# -> 2037             data = self._reader.read(nrows)
#    2038         except StopIteration:
#    2039             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# ValueError: could not convert string to float: '5098+'

# %% [markdown]
# From the above error, it is evident that the data types of the columns cannot be forced upon them, since there are a couple of string entries like '5098+' under one of the numeric columns. In that case, the plus sign can be removed after reading the csv files, and then the data types of the columns can be enforced.

# %%
df = pd.read_csv("csv_files/cricket_data.csv", 
                 usecols=list(column_types.keys()))
# Just for the purpose of examining the occurrences of NaN,
# since the count() function cannot count the number of NaNs
df.fillna("-", inplace=True)

# %% [markdown]
# The values in some columns need to be checked before deciding on how to form the tables out of this dataset.

# %%
df.groupby("Playing role")["Playing role"].count()
# Out:
# Playing role
# -                             86590
# 12th man                         17
# Allrounder                      735
# Batsman                         369
# Batsman, Batsman                  1
# Batting allrounder               35
# Bowler                         1083
# Bowling allrounder               34
# Middle-order batsman            297
# Opening batsman                 321
# Top-order batsman               236
# Wicketkeeper                    328
# Wicketkeeper batsman            261
# Wicketkeeper, Wicketkeeper        1
# Name: Playing role, dtype: int64

# %%
df.shape[0] - df.groupby("Batting style")["Batting style"].get_group("-").count()
# Out:
# 57252

# %%
df.shape[0] - df.groupby("Bowling style")["Bowling style"].get_group("-").count()
# Out:
# 44085

# %%
df.shape
# Out:
# (90308, 41)

# %%
for (teams, row) in zip(df.groupby("Major teams")["Major teams"].count().index, df.groupby("Major teams")["Major teams"].count()):
    print("{team} = {count}".format(team=teams, count=row))
# Out:
# - = 6271
# A Lyth's XI = 1
# A to K = 2
# AA Jasdenwala's XI = 1
# AA Priestley's XI = 1
# AB St Hill's XII = 7
# ACB Chairman's XI = 1
# ACC = 8
# AFS = 23
# AJ Webbe's XI = 1
# AJK Jaguars = 7
# AL Ghurair Construction = 20
# AL Naboodah Tigers = 15
# AM Wood's XI = 1
# AMC Abbottabad = 16
# AMCC Ajman = 25
# AP Institute of Information Technology = 17
# APS = 15
# AU Finja = 9
# AWR 1 = 15
# AWR 2 = 15
# AWR 3 = 12
# Abahani Limited = 4
# Abbottabad = 19
# Abbottabad Falcons = 11
# Abbottabad Region = 4
# Abbottabad Rhinos = 18
# Abdul Wali Khan University Nowshera = 11
# Abela and Co = 27
# Aboriginal & Torres Strait Islander Commission XI = 1
# Aboriginal XI = 4
# Aboriginal XI Women = 9
# Abu Dhabi United = 9
# Abu Dhabi XI = 9
# Adam Global Dubai = 18
# Adelaide Strikers Women = 3
# Adnoc Al Ruwais = 10
# Affies = 5
# Afghan Cheetas = 1
# Afghan Rangers Cricket Club = 15
# Afghan Wireless Cricket Club = 12
# Afghanistan = 27
# Afghanistan Disable = 18
# Afghanistan Under-17s = 2
# Afghanistan Under-19s = 32
# Afghanistan Under-25s = 1
# Agrani Bank Cricket Club = 17
# Agriculture Development Bank of Pakistan = 7
# Ahmed Star CC = 9
# Air Arabia = 12
# Air India = 5
# Air India Red = 1
# Air India Women = 7
# Ajax = 1
# Ajmer Meru Warriors = 25
# Al Futtaim Carillion = 14
# Al Futtaim Exova = 11
# Al Gurg CC = 14
# Al Jaber Blazer = 17
# Al Jaber Plus Friends = 13
# Al Jeer CC = 18
# Al Mumtaz = 9
# Al Sharqi Ship Company LLC = 9
# Albert TUTI Patriots = 9
# Alec = 15
# Alec Warriors = 12
# Aligarh University Past and Present = 2
# All England Eleven = 4
# All India Electricity Board = 4
# All India XI = 5
# Alliance Insurance = 24
# Allied Bank = 6
# Alwarpet Cricket Club = 4
# Amakhosi = 3
# American Born = 9
# American Education Center = 14
# Americas Under-15s = 1
# Americas Women = 1
# Amo Region = 26
# Amo Region Under-16s = 11
# Amo Sharks = 10
# Ampara Combine Schools = 10
# Ananda College = 30
# Anantara Falcons = 17
# Andhra = 220
# Andhra Cricket Association XI = 5
# Andhra Under-14s = 13
# Andhra Under-16s = 1
# Andhra Under-19s = 1
# Andhra Under-22s = 1
# Andhra Under-25s = 6
# Andhra Women = 10
# Andover = 7
# Angaar = 11
# Angledale (Far South Coast of NSW Association) = 1
# Anguilla = 15
# Antigua = 1
# Antigua Masterblasters = 9
# Antigua and Barbuda = 12
# Antonians Sports Club = 70
# Anuradhapura Central College = 15
# Aptech Cricket Club = 14
# Arabian Rangers = 7
# Arenco IT = 13
# Argentina = 69
# Argentina Under-19s = 28
# Argentina Women = 19
# Armed Police Force Club = 3
# Army = 51
# Army (South Africa) = 9
# Army and Navy = 2
# Arunachal Pradesh = 29
# Arya Gurukul (CBSE) = 11
# Asian CC = 16
# Asian Eagles = 9
# Asian Eagles Etis = 9
# Asian Falcon = 15
# Asian Tigers = 12
# Assam = 270
# Assam Cricket Association XI = 3
# Assam Governor's XI = 1
# Assam Under-14s = 13
# Assam Under-16s = 18
# Assam Under-19s = 11
# Assam Under-22s = 2
# Assam Women = 12
# Atlantic Region = 9
# Attock Refinery Limited = 1
# Auckland = 301
# Auckland A = 7
# Auckland Second XI = 2
# Auckland Under-17s = 3
# Auckland Under-21s Women = 13
# Auckland Women = 23
# Australia = 11
# Australia A Women = 2
# Australia Blind = 14
# Australia Governor-General's XI = 6
# Australia Masters = 2
# Australia Under-15s = 7
# Australia Under-16s = 25
# Australia Under-19s = 78
# Australia Under-19s Women = 5
# Australia Under-21s Women = 1
# Australia Under-23s Women = 4
# Australia Young Cricketers = 9
# Australian Capital Territory = 102
# Australian Capital Territory Second XI Women = 1
# Australian Capital Territory Under-15s = 8
# Australian Capital Territory Under-15s Women = 13
# Australian Capital Territory Under-17s = 15
# Australian Capital Territory Under-19s = 29
# Australian Capital Territory Under-19s Women = 5
# Australian Capital Territory Under-23s = 14
# Australian Capital Territory Women = 17
# Australian Combined Universities = 17
# Australian Country XI = 1
# Australian Cricket Academy = 4
# Australian Cricketers' Association Masters = 2
# Australian Imperial Forces = 1
# Australian Indiginous = 7
# Australian Institute of Sports = 2
# Australian Institute of Sports Second XI = 1
# Australian Services = 2
# Australian Universities = 36
# Australians = 3
# Austria = 35
# Austria Under-17s = 13
# Averda = 16
# Azad Sporting Club = 18
# BAT Sports = 5
# BAWA United CC = 8
# BCA President's XI = 2
# BJT Bosanquet's XI = 2
# BK Gulf LLC = 12
# BMCC Dubai = 12
# Bad Boys = 8
# Bad Boyz = 3
# Badulla & Monaragala Combine Schools = 43
# Badulla Ladies = 2
# Badureliya Sports Club = 14
# Bafco = 10
# Baghlan Province Under-16s = 10
# Baghlan Province Under-17s = 17
# Bahamas = 32
# Bahamas Under-15s = 10
# Bahamas Under-19s = 20
# Baharain Bravehearts = 9
# Bahawalpur = 177
# Bahawalpur Region = 2
# Bahawalpur Stags = 7
# Bahrain = 69
# Bahrain Under-16s = 10
# Bahrain Under-19s = 36
# Bailey's Bay Cricket Club = 1
# Bairnsdale and Sale-Maffra Combined XI = 11
# Balkh Province = 16
# Balkh Province Under-16s = 13
# Balkh Province Under-17s = 17
# Ball Burners = 8
# Baluchistan = 10
# Baluchistan Governor's XI = 1
# Band-e-Amir Dragons = 6
# Band-e-Amir Region = 16
# Band-e-Amir Region Under-16s = 3
# Bangalore Brigadiers (Urban) = 15
# Bangalore Provident (Rural) = 10
# Bangladesh = 48
# Bangladesh A = 1
# Bangladesh Boys Club = 19
# Bangladesh Cricket Board Green = 1
# Bangladesh Cricket Board XI = 4
# Bangladesh Krira Shikkha Protisthan = 22
# Bangladesh Under-15s = 7
# Bangladesh Under-17s = 25
# Bangladesh Under-19s = 41
# Bangladesh Under-21s = 1
# Bangladesh Women = 39
# Barbados = 275
# Barbados Select = 4
# Barbados Under-19s = 8
# Barbados Women = 17
# Barbados XI = 2
# Baridhara Dazzlers = 16
# Barisal Division = 54
# Barisal Division Under-14s = 16
# Barisal Division Under-16s = 18
# Barisal Division Under-18s = 20
# Baroda = 205
# Baroda Cricket Association XI = 5
# Baroda Under-16s = 7
# Baroda Under-19s = 4
# Baroda Under-22s = 1
# Baroda Women = 11
# Bashley (Rydal) = 4
# Basilica College = 8
# Bath = 6
# Batticaloa Combine Schools = 7
# Bedfordshire = 137
# Been Chakwal CC = 11
# Belagavi Panthers = 38
# Belgium = 30
# Belgium Under-15s = 5
# Belgium Under-17s = 8
# Belgium Under-19s = 24
# Belgrano Athletic Club = 1
# Belize = 26
# Bellary Tuskers = 27
# Bengal = 262
# Bengal Governor's XI = 14
# Bengal Under-14s = 24
# Bengal Under-16s = 18
# Bengal Under-19s = 18
# Bengal Women = 16
# Bengaluru Blasters = 5
# Berbice = 32
# Berkshire = 97
# Berkshire Women = 21
# Bermuda = 103
# Bermuda Development XI = 13
# Bermuda Under-15s = 6
# Bermuda Under-19s = 25
# Bermuda Women = 33
# Bhairahawa Gladiators = 3
# Bharat Petroleum Corporation Limited = 1
# Bharat Sanchar Nigam Limited = 2
# Bhutan = 25
# Bhutan Under-19s = 28
# Bhutan Women = 18
# Bihar = 43
# Bihar Governor's XI = 2
# Bihar Under-14s = 18
# Bihar Under-16s = 18
# Bihar Under-19s = 3
# Bihar Under-22s = 8
# Bihar Women = 1
# Bijapur Bulls = 40
# Bikaner Desert Challengers = 20
# Biman Bangladesh = 5
# Biratnagar Kings = 8
# Biratnagar Warriors = 2
# Birmingham and District Cricket League = 1
# Black = 8
# Black Hawks = 14
# Blackheath = 2
# Blighty Ducks = 15
# Bloemendaal = 1
# Bloomfield Cricket and Athletic Club = 69
# Blue = 6
# Blue Strikers = 15
# Blue Warriors = 9
# Boland = 133
# Boland Academy = 3
# Boland Under-13s = 50
# Boland Under-15s = 32
# Boland Under-17s = 34
# Boland Under-19s = 44
# Boland Women = 44
# Boland and Western Province Combined Academy XI = 4
# Bolt CC = 8
# Bombay = 1
# Bombay Chief Minister's XI = 3
# Bombay Cricket Association President's XI = 1
# Bombay Governor's XI = 1
# Bombay Pilgrims = 2
# Bombay Women = 1
# Boost Defenders = 8
# Boost Region = 23
# Boost Region Under-16s = 7
# Border = 332
# Border B = 1
# Border Country Districts = 12
# Border Under-13s = 49
# Border Under-15s = 31
# Border Under-17s = 38
# Border Under-19s = 61
# Border Women = 30
# Bost Atlan = 11
# Botswana = 34
# Botswana Under-19s = 48
# Botswana Women = 14
# Bournemouth Sports = 1
# Brasilia Cricket Club = 18
# Brazil = 6
# Brazil Women = 34
# Brighton = 14
# Brighton College = 8
# Brisbane Heat Women = 1
# Bristol University = 10
# British Guiana = 213
# British Universities = 2
# British Virgin Islands = 15
# Bromley Cricket Club = 3
# Brothers Union = 5
# Brunei = 20
# Brunei Under-19s = 12
# Buckinghamshire = 105
# Buckinghamshire Women = 49
# Bulgaria = 19
# Burgher Recreation Club = 80
# Burma = 23
# Burma Under-19s = 8
# Burnley = 1
# Bury St Edmunds = 1
# Business Management School = 15
# Butt XI = 29
# C Lennox's XI = 6
# CC Boys = 8
# CK Nayudu's XI = 1
# CWW.Kannangara College = 8
# CYC Attariya = 11
# Calmore Sports = 11
# Cambridge Cricket Club = 2
# Cambridge MCCU = 40
# Cambridge Town Club = 92
# Cambridge Town XI = 2
# Cambridge Town and County Club = 1
# Cambridge UCCE = 1
# Cambridge Union Club = 4
# Cambridge University = 816
# Cambridge University Women = 31
# Cambridge and Oxford Universities = 1
# Cambridgeshire = 143
# Cambridgeshire Women = 3
# Cambridgeshire and Huntingdonshire Women = 46
# Canada = 131
# Canada Under-15s = 14
# Canada Under-19s = 64
# Canada Women = 32
# Canada and United States of America = 15
# Canadian Invitation XI = 5
# Candyland = 1
# Canpack = 13
# Canterbury = 362
# Canterbury A = 2
# Canterbury Invitation XI = 1
# Canterbury Second XI = 1
# Canterbury Under-17s = 2
# Canterbury Under-21s Women = 8
# Canterbury Women = 22
# Captain Blagrave's XI = 1
# Captains = 14
# Cardiff MCCU = 33
# Cardiff UCCE = 3
# Carioca Cricket Club = 15
# Cayman Islands = 40
# Cayman Islands Under-15s = 11
# Cayman Islands Under-19s = 14
# Cayman Islands Women = 14
# Centaur Warriors = 11
# Central Development Region = 1
# Central Districts = 150
# Central Districts A = 9
# Central Districts Second XI = 2
# Central Districts Under-17s = 1
# Central Districts Under-21s Women = 4
# Central Districts Women = 37
# Central East Region = 14
# Central Excise & Customs = 3
# Central India = 20
# Central Province = 12
# Central Province Women = 8
# Central Provinces and Berar = 48
# Central Trinidad = 16
# Central West Region = 12
# Central Women = 7
# Central Zone = 1
# Central Zone Blues Women = 4
# Central Zone Greens Women = 5
# Centrals = 2
# Centurion Hoerskool = 12
# Ceylon = 139
# Chandigarh Cheetaas = 16
# Charging Leopards = 7
# Charlbury Women CC = 9
# Chemplast = 3
# Chennai Superstars = 1
# Chepauk Super Gillies = 11
# Chertsey = 1
# Cheshire = 135
# Cheshire Women = 25
# Chhattisgarh = 24
# Chhattisgarh Cricket Association XI = 7
# Chilaw Marians Cricket Club = 50
# Chile Women = 14
# China = 74
# China Under-19s = 13
# China Women = 57
# Chittagong Division = 34
# Chittagong Division Under-14s = 14
# Chittagong Division Under-16s = 18
# Chittagong Division Under-18s = 14
# Chittors Chetak = 22
# Chitwan Rhinos = 1
# Chitwan Tigers = 3
# City Club = 19
# Civil Service = 8
# Cleveland County Cricket Club = 1
# Coast Pekee = 12
# Cobras (UAE) = 19
# Cobras Cubs = 4
# Coca Cola = 43
# Colombo Cricket Club = 61
# Colombo Cricket Club Women = 4
# Colombo Young Women Cricket Club = 15
# Colonel Byng's XI = 1
# Colors X-Factors = 4
# Colts Cricket Club = 83
# Colts Cricket Club Women = 34
# Combined Campuses and Colleges = 24
# Combined Districts XI = 15
# Combined Islands = 3
# Combined Province Women = 4
# Combined Services = 52
# Combined Trinidad and British Guiana = 1
# Combined USA and Canada = 9
# Combined Universities = 7
# Combined XI (Australia) = 4
# Commercial Bank = 12
# Comptroller and Auditor General = 2
# Comsats Islamabad = 26
# Cook Islands = 3
# Corner Tigers = 13
# Cornwall = 123
# Cornwall Women = 29
# Costa Rica = 14
# Cousins CC = 12
# Crescent Club of Lahore = 3
# Cricket Association of Bengal Under-17s = 18
# Cricket Association of Bengal XI = 5
# Cricket Australia Chairman's XI = 1
# Cricket Club of India = 12
# Cricket Coaching School = 4
# Cricket Hong Kong Independents XI = 5
# Cricket Star XI = 4
# Croatia = 19
# Culford School Headmaster's XI = 6
# Cumberland = 134
# Cumbria Women = 37
# Cyprus = 27
# Cyprus Under-15s = 12
# Czech Republic = 27
# D.A.V College (Chandigarh) = 22
# DBMSC A = 16
# DBMSC B = 28
# DG Cheetahs = 13
# DHL Sharjah = 16
# DHL United = 27
# DIB Knight Riders = 11
# DIB Stars = 10
# DIC Fighters = 12
# DR Jardine's XI = 7
# DS Senanayake College = 30
# DSR Sports Select XI = 7
# DXB Municipality = 13
# DXB Panthers = 13
# DXB Warriors = 10
# Dacca = 4
# Dacca University = 25
# Dadu = 1
# Dadu Cricket Association = 15
# Dancan Sports Club = 8
# Danube Lions = 6
# Darwin Cricket Club = 1
# Dawood Club = 1
# De Mazenod College = 19
# Debarawewa Central College = 15
# Defence Housing Authority = 1
# Dehradun Devils = 20
# Delhi = 205
# Delhi Daredevils = 1
# Delhi Kings = 17
# Delhi Under-14s = 11
# Delhi Under-16s = 13
# Delhi Under-19s = 8
# Delhi Women = 17
# Demerara = 12
# Demobilised Officers = 1
# Denmark = 60
# Denmark A = 2
# Denmark Under-15s = 13
# Denmark Under-17s = 5
# Denmark Under-19s = 47
# Denmark Women = 32
# Dera Ismail Khan = 38
# Dera Murad Jamali Ibexes = 8
# Derbyshire = 351
# Derbyshire 2nd XI = 62
# Derbyshire Cricket Board = 25
# Derbyshire Women = 23
# Derbyshire XI = 2
# Desert Group Heros = 14
# Devapathiraja College = 13
# Devon = 127
# Devon Women = 21
# Dewa = 13
# Dhaka Division = 25
# Dhaka Division North Under-14s = 14
# Dhaka Division North Under-16s = 18
# Dhaka Division North Under-18s = 14
# Dhaka Division South Under-14s = 15
# Dhaka Division South Under-16s = 18
# Dhaka Division South Under-18s = 17
# Dhaka Dynamites = 1
# Dhaka Metro Under-14s = 14
# Dhaka Metro Under-16s = 18
# Dhaka Metro Under-18s = 18
# Dhaka Metropolis = 9
# Dhangadhi Stars = 1
# Dhangadhi Team Chauraha = 2
# Dhangadhi XI = 13
# Dharmaraja College = 15
# Dharmashoka College = 11
# Dharti TV = 15
# Dharwad Zone = 1
# Dhoom 8 = 23
# Diamonds = 2
# Diasqua Little Sai Wan Cricket Club = 8
# Dindigul Dragons = 13
# Discovery Garden = 19
# Dolmen Tourism = 12
# Dolphins Cubs = 3
# Dominica = 6
# Dominica Women = 28
# Dominions = 1
# Dorset = 94
# Dorset Women = 48
# Dr CR Pereira's XI = 4
# Dr DY Patil Sports Academy = 8
# Dream Killers = 11
# Dubai Bulls = 8
# Dubai Destroyers = 10
# Dubai Indians = 11
# Dubai Municipality = 14
# Dubai Night Riders = 19
# Dubai Qalandars = 11
# Dubai Strikers = 17
# Dubai Tigers = 16
# Dubai Tigers 11 = 14
# Dubai Zalmi = 17
# Dublin University = 28
# Duke Boys = 14
# Durham = 74
# Durham 2nd XI = 42
# Durham Cricket Board = 11
# Durham MCCU = 46
# Durham UCCE = 4
# Durham University = 13
# Durham Women = 26
# Dutco Construction LLC = 12
# E Bligh's XI = 2
# EH Budd's XI = 5
# EJ Sanders' XI = 2
# EW Swanton's XI = 1
# Eagles = 24
# Eagles (UAE) = 8
# Ealing = 1
# Earl of Darnley's XI = 1
# Earl of Winchilsea's XI = 6
# East Africa = 62
# East Coast Women = 2
# East Kent = 6
# East Pakistan = 58
# East Pakistan Railways = 7
# East Trinidad = 31
# East Zone = 1
# East Zone Women = 6
# East and Central Africa = 20
# East of England = 3
# East-West Information = 2
# Eastbourne CC = 8
# Eastern Aces = 2
# Eastern Lions = 10
# Eastern Province = 354
# Eastern Province (SACB) = 78
# Eastern Province Country Districts = 13
# Eastern Province Invitation XI = 19
# Eastern Province Ladies = 15
# Eastern Province Under-13s = 51
# Eastern Province Under-15s = 26
# Eastern Province Under-17s = 35
# Eastern Province Under-19s = 49
# Eastern Province Women = 62
# Eastern Punjab = 25
# Eastern Suburbs = 1
# Eastern Transvaal = 14
# Eastern Transvaal Country Districts = 13
# Easterns = 58
# Easterns (Zimbabwe) = 1
# Easterns Under-13s = 47
# Easterns Under-15s = 42
# Easterns Under-17s = 30
# Easterns Under-19s = 46
# Easterns Under-19s Women = 8
# Easterns Women = 55
# Easterns XI = 2
# Edmonton Royals = 2
# Eleven Aces = 13
# Emeralds = 9
# Emerging Cape Cobras = 2
# Emerson College Multan = 24
# Emicool = 18
# Emirates Cricket Board XI = 2
# Emirates Hurricane = 9
# Emirates Islamic Bank Invitation XI = 5
# Emrill Cricket Club = 16
# Enfield = 1
# England = 102
# England Academy Women = 2
# England Blind = 1
# England Cricket Board Development Women's XI = 2
# England Development Squad Women = 1
# England National Cricket Association XI = 1
# England Under-15s = 3
# England Under-19s = 4
# England Under-23 Women = 1
# England Women = 26
# England Women's Academy/Surrey Boys = 3
# England XI = 1
# England Young Cricketers = 2
# English Residents = 17
# Enoc = 12
# Eppco = 17
# Epsom = 5
# Essequibo = 10
# Essex = 243
# Essex 2nd XI = 48
# Essex Cricket Board = 19
# Essex Under-13s = 1
# Essex Women = 23
# Essex XI = 7
# Estonia = 21
# Etisalat Cricket Club = 14
# Etisalat Royals = 9
# Eton College = 30
# European University of Bangladesh = 16
# Europeans (India) = 367
# Evacuee Trust Property Board = 10
# Evergreen = 23
# Eversley = 11
# Excelsior = 1
# Expert Dhangadi = 1
# Express Ndovus = 4
# F Beauclerk's XI = 8
# FATA Cheetas = 9
# FATA Region = 5
# FOG-Seenigama = 12
# FOG-Seenigama Ladies = 28
# Faisal 11 = 27
# Faisalabad = 167
# Faisalabad Region = 5
# Faisalabad Wolves = 21
# Faislabad Women Cricket Association = 1
# Falcon XI = 16
# Falcons = 22
# Falkland Islands = 13
# Federally Administered Tribal Areas = 25
# Fiji = 121
# Fiji Under-19s = 48
# Findon Cricket Club = 11
# Finland = 31
# Fly Emirates XI = 13
# Force 8 = 8
# Framesby High School = 11
# France = 50
# France Under-15s = 7
# France Under-17s = 5
# France Under-19s = 26
# Free Foresters = 42
# Free State = 41
# Free State Under-13s = 49
# Free State Under-15s = 27
# Free State Under-17s = 31
# Free State Under-19s = 38
# Free State Women = 37
# Freelooters = 2
# Friends 4 Ever = 10
# Friends CC = 10
# Friends Fujairah = 11
# G Anderson's XI = 2
# G Osbaldeston's XI = 8
# G Parr's XI = 1
# G9-Stars = 8
# GJV Weigall's XI = 6
# GS Patterson's XI = 2
# Galaxy Gladiators Lantau = 2
# Galle Cricket Club = 69
# Gambia = 24
# Gambia Under-19s = 14
# Gargash Smashers = 11
# Gauteng = 45
# Gauteng B = 3
# Gauteng Under-13s = 48
# Gauteng Under-15s = 35
# Gauteng Under-17s = 23
# Gauteng Under-19s = 33
# Gauteng Women = 41
# Gauteng XI = 1
# Gazi Group Cricketers = 3
# Gazi Tank Cricketers = 1
# Gentlemen = 23
# Gentlemen of Canada = 1
# Gentlemen of England = 32
# Gentlemen of India = 3
# Gentlemen of Kent = 50
# Gentlemen of Kent and Sussex = 2
# Gentlemen of Middlesex = 1
# Gentlemen of Nottinghamshire = 1
# Gentlemen of Southwell = 1
# Gentlemen of Surrey and Sussex = 3
# Gentlemen of the North = 27
# Gentlemen of the South = 10
# Germany = 54
# Germany Under-15s = 4
# Germany Under-17s = 4
# Germany Under-19s = 14
# Ghana = 19
# Ghana Under-19s = 34
# Gibraltar = 77
# Gibraltar Under-15s = 5
# Gibraltar Under-17s = 3
# Gibraltar Under-19s = 8
# Giffin Traffiks = 18
# Glamorgan = 175
# Glamorgan 2nd XI = 41
# Glamorgan Cricket Board = 1
# Glenwood High School = 9
# Gloucestershire = 309
# Gloucestershire 2nd XI = 50
# Gloucestershire Academy = 2
# Gloucestershire Cricket Board = 14
# Gloucestershire Under-14s = 1
# Gloucestershire Women = 26
# Go Green = 12
# Goa = 149
# Goa Cricket Association XI = 1
# Goa Under-14s = 1
# Goa Under-16s = 33
# Goa Under-19s = 9
# Goa Under-22s = 8
# Goa Women = 12
# Godalming = 11
# Gold Coast = 2
# Gorbat Cricket Club = 14
# Gordon = 1
# Government College Murree = 19
# Governor's XI = 1
# Govt. Post Graduate Samanabad Faisalabad = 11
# Great Britain = 8
# Great Britain Combined University Team = 3
# Greece = 22
# Greece Under-17s = 13
# Grenada = 15
# Grenada Women = 23
# Grey College = 15
# Grey High School = 16
# Griqualand West = 307
# Griqualand West Under-13s = 33
# Griqualand West Under-15s = 22
# Griqualand West Under-17s = 29
# Griqualand West Under-19s = 41
# Griqualand West Women = 22
# Guernsey = 20
# Guernsey Under-15s = 19
# Guernsey Under-19s = 46
# Gujarat = 294
# Gujarat Cricket Association XI = 8
# Gujarat Lions = 16
# Gujarat Lions (UAE) = 16
# Gujarat President's XI = 2
# Gujarat Under-16s = 6
# Gujarat Under-19s = 2
# Gujarat Women = 13
# Gujranwala Cricket Association = 85
# Gurugram Spartans = 23
# Guyana = 87
# Guyana Board President's XI = 1
# Guyana Police Force Team = 1
# Guyana President's Select XI = 1
# Guyana Under-19s = 22
# Guyana Women = 25
# Gwalior = 9
# H Philipson's XI = 1
# HBS = 2
# HC Woolridge's XI = 2
# HCC = 5
# HCC Women = 1
# HDG Leveson-Gower's XI = 12
# HK Foster's XI = 9
# HLG Stars = 8
# HT Hewett's XI = 1
# HW University Dubai (UAE) = 16
# Habib Bank Limited = 13
# Hambantota District = 2
# Hambledon XII = 1
# Hampshire = 458
# Hampshire 2nd XI = 51
# Hampshire Cricket Academy = 3
# Hampshire Cricket Board = 14
# Hampshire Women = 20
# Hampshire XI = 34
# Hampshire and Surrey = 2
# Hamriya XI = 9
# Haripur Cricket Association = 1
# Harrow School = 37
# Haryana = 169
# Haryana Hammers = 1
# Haryana Under-14s = 14
# Haryana Under-19s = 6
# Haryana Under-22s = 1
# Haryana Women = 11
# Hatfield Sports Club = 1
# Hatton National Bank = 1
# Havant = 4
# Hawke's Bay = 130
# Hawks (UAE) = 11
# Hawks XI = 12
# Hawthorn = 1
# Hazara Division Cricket Association = 36
# Hazara University Abbottabad = 11
# Heidelberg Warriors = 10
# Helmand Province Under-16s = 15
# Helmand Province Under-17s = 19
# Help for Heroes XI = 1
# Herat Province Under-16s = 18
# Herefordshire = 91
# Hermes DVS = 3
# Hertfordshire = 135
# Hertfordshire Women = 43
# High Star Medical CC = 8
# High Wycombe CC = 11
# Higher Education Commission Women = 15
# Highlanders = 4
# Highveld Women = 4
# Hilton College = 7
# Himachal Pradesh = 170
# Himachal Pradesh Cricket Association XI = 9
# Himachal Pradesh Under-16s = 8
# Himachal Pradesh Under-19s = 9
# Himachal Pradesh Women = 11
# Hindus = 77
# Hindus and Muslims = 4
# Hindus and Rest = 4
# Hindus and The Rest = 1
# Hobart Hurricanes = 1
# Hobart Hurricanes Women = 1
# Hoer Volkskool = 9
# Holkar = 18
# Homerton = 4
# Hong Kong = 125
# Hong Kong Cricket Association Under-19s = 11
# Hong Kong Cricket Club = 28
# Hong Kong Dragons = 22
# Hong Kong Island United = 1
# Hong Kong Under-16s = 10
# Hong Kong Under-19s = 30
# Hong Kong Women = 46
# Hornchurch = 5
# Houghton Main Cricket Club = 11
# House Building Finance Corporation = 19
# Hubli Tigers = 23
# Hudson Park = 6
# Hulas Kathmandu Royals = 2
# Hung Hom Jaguars = 2
# Hunters = 16
# Huntingdonshire = 18
# Hurlingham Club = 2
# Hurst Park Club = 1
# Hyderabad (India) = 224
# Hyderabad (India) Women = 7
# Hyderabad (Pakistan) = 150
# Hyderabad Blues (India) = 1
# Hyderabad Cricket Association A = 1
# Hyderabad Cricket Association Colts XI = 5
# Hyderabad Cricket Association XI = 7
# Hyderabad Education Board = 7
# Hyderabad Hawks = 19
# Hyderabad Region = 7
# Hyderabad Under-14s = 14
# Hyderabad Under-16s = 3
# Hyderabad Under-19s = 11
# Hyderabad Under-22s = 3
# Hyderabad Under-25s = 6
# I Zingari = 9
# I&M Bank Nyatis = 3
# IA Healy XII = 1
# IC Boyz = 9
# ICBT Campus (Sri Lanka) = 19
# ICC Associates Young Cricketers = 2
# Icons = 24
# Idream Karaikudi Kaalai = 3
# Ilford CC = 13
# Ilford Town CC = 14
# Income Tax = 7
# Income Tax (India) = 3
# Independents = 9
# India = 86
# India A Under-19s = 9
# India A Women = 3
# India B Under-19s = 11
# India B Women = 2
# India Blind = 14
# India Blue Women = 4
# India Cements = 1
# India Disable = 15
# India Green Women = 11
# India Pistons Cricket Club = 1
# India Red Women = 2
# India Revenue = 1
# India Senior Women = 1
# India Under-15s = 1
# India Under-17s = 1
# India Under-19s = 52
# India Under-21s Women = 5
# India Women = 38
# India Young Cricketers = 1
# Indian Air Force = 3
# Indian Bank Sports Recreation Club = 5
# Indian Board President's XI = 1
# Indian Colts XI = 1
# Indian Oil Corporation XI = 1
# Indian Overseas Bank = 3
# Indian Starlets XI = 4
# Indian Tobacco Company = 6
# Indian Universities = 7
# Indian Universities and Under-22s XI = 1
# Indian University Occasionals = 1
# Indira Road Krira Chakra = 23
# Indonesia = 28
# Indonesia Women = 20
# Industrial Development Bank of Pakistan = 2
# Infinity = 12
# Inkatha = 9
# International Islamic University Islamabad = 11
# International Schools Combined = 2
# International XI = 1
# International XI Women = 12
# Invitation XI = 3
# Iran = 16
# Iran Under-19s = 10
# Ireland = 258
# Ireland A = 1
# Ireland A Women = 2
# Ireland Development XI = 1
# Ireland Under-15s = 23
# Ireland Under-17s = 2
# Ireland Under-17s Women = 6
# Ireland Under-19s = 48
# Ireland Women = 65
# Isipathana College = 13
# Islamabad = 35
# Islamabad Cricket Association = 84
# Islamabad Leopards = 12
# Islamabad Model College Rawalpindi = 10
# Islamabad Region = 1
# Islamia College Peshawar = 16
# Islamia College Sialkot = 16
# Islamia University Bahawalpur = 19
# Isle of Man = 22
# Isle of Man Under-15s = 4
# Isle of Man Under-17s = 2
# Isle of Man Under-19s = 15
# Israel = 79
# Israel Under-19s = 11
# Italy = 29
# Italy Under-15s = 8
# Italy Under-17s = 3
# Italy Under-19s = 40
# Itefaq Cricket Club = 13
# JG Greig's XI = 1
# Jaffna Central College = 12
# Jaffna Combine Schools = 28
# Jagdamba Rhinos = 6
# Jain Bangalore = 10
# Jaipur Jaguars = 13
# Jaipur Pink City Royals = 21
# Jaisalmer Jaguars = 22
# Jamaica = 271
# Jamaica Select XI = 5
# Jamaica Under-19s = 11
# Jamaica Women = 27
# Jammu & Kashmir = 324
# Jammu & Kashmir Under-14s = 17
# Jammu & Kashmir Under-16s = 8
# Jammu & Kashmir Under-19s = 15
# Jammu & Kashmir Under-22s = 1
# Jammu & Kashmir Women = 15
# Jammu and Kashmir = 4
# Japan = 54
# Japan Under-19s = 12
# Japan Women = 47
# Jersey = 22
# Jersey Under-15s = 19
# Jersey Under-17s = 1
# Jersey Under-19s = 24
# Jharkhand = 3
# Jharkhand Under-19s = 10
# Jharkhand Women = 11
# Jinnah Degree College Karachi (Pakistan) = 15
# Jodhpur Jodhana Royals = 26
# John Keells Group = 2
# Jolly Rovers Cricket Club = 1
# Jones TUTI Patriots = 4
# K & M Combined Schools = 2
# KC Gandhi English School = 11
# KC Ibrahim's XI = 1
# KSCA Colts XI = 1
# Kabul Cricket Club = 13
# Kabul Eagles = 3
# Kabul Green = 5
# Kabul Kings = 2
# Kabul Province = 17
# Kabul Province Under-16s = 12
# Kabul Province Under-17s = 17
# Kabul Region = 1
# Kabul Zalmi = 7
# Kala Bagan Krira Chackra = 1
# Kalabagan Cricket Academy = 2
# Kalabagan Krira Chakra = 4
# Kalat = 13
# Kalutara Physical Culture Club = 22
# Kalutara Town Club = 24
# Kalutara Vidyalaya = 15
# Kaluthara Maha Vidyalaya = 11
# Kampong = 3
# Kanbis Tigers = 3
# Kanchanpur Iconic = 4
# Kandahar Province = 20
# Kandahar Province Under-16s = 11
# Kandahar Province Under-17s = 15
# Kandurata Province Women = 2
# Kandy Cricket Club = 24
# Kandy Customs Cricket Club = 9
# Kandy Youth Cricket Club = 32
# Kandyan Ladies Cricket Club = 3
# Kannur XI = 8
# Kantipur Gurkhas = 4
# Kapisa Province = 11
# Kapisa Province Under-16s = 14
# Karachi = 246
# Karachi Blues = 13
# Karachi Cricket Association Blues = 5
# Karachi Dolphins = 4
# Karachi Education Board = 7
# Karachi Port Trust = 5
# Karachi Region Blues = 1
# Karachi University = 44
# Karachi Whites = 22
# Karachi Zebras = 9
# Karachi and Bahawalpur = 1
# Karaikudi Kaalai = 13
# Karandeniya Central College = 17
# Karnataka = 130
# Karnataka Institute of Cricket = 3
# Karnataka State Cricket Association = 1
# Karnataka State Cricket Association Colts XI = 1
# Karnataka State Cricket Association President's XI = 7
# Karnataka State Cricket Association XI = 3
# Karnataka Under-14s = 7
# Karnataka Under-16s = 9
# Karnataka Under-19s = 13
# Karnataka Under-22s = 2
# Karnataka Under-25s = 3
# Karnataka Women = 9
# Karnataka XI = 2
# Kathiawar = 2
# Kathmandu Goldens = 5
# Kathmandu Kings XI = 5
# Kazmi Knight Riders = 9
# Kei = 17
# Kei Women = 62
# Kelburne CC (Paisley) = 1
# Kent = 446
# Kent 2nd XI = 60
# Kent Cricket Board = 17
# Kent Under-19s = 2
# Kent Women = 14
# Kent XI = 26
# Kenya = 38
# Kenya A = 3
# Kenya Elite = 1
# Kenya Under-15s = 7
# Kenya Under-19s = 60
# Kenya Women = 36
# Kerala = 295
# Kerala Cricket Association XI = 6
# Kerala Under-14s = 17
# Kerala Under-16s = 7
# Kerala Under-19s = 5
# Kerala Under-22s = 1
# Kerala Under-25s = 1
# Kerala Women = 24
# Kersney = 7
# Khairpur Cricket Association = 36
# Khaleej Times = 31
# Khan Research Laboratories = 7
# Khan Research Labs = 4
# Khelaghar Samaj Kallyan Samity = 21
# Khiladi = 12
# Khiladi 786 = 4
# Khoat CC = 8
# Khost Province = 22
# Khost Province Under-16s = 14
# Khost Province Under-17s = 11
# Khulna = 1
# Khulna Division = 39
# Khulna Division Under-14s = 15
# Khulna Division Under-16s = 18
# Khulna Division Under-18s = 19
# Khyber Pakhtunkhwa = 1
# Kibworth = 3
# Kibworth Cricket Club = 3
# Kilinochchi Combined Schools = 15
# King Edward VII High School = 7
# Kingborough = 1
# Kings XI Punjab = 1
# Kingswood College = 7
# Kingswood College (Kandy) = 15
# Knights Cubs = 3
# Knights Women = 3
# Kochian Province = 9
# Kohat CC = 3
# Kohinoor Cricket Club = 3
# Kolkata Knight Riders = 3
# Kolkata Tigers = 1
# Kon. UD = 1
# Kongonis = 9
# Kota Chambal Tigers = 22
# Kotelawala Defence University = 15
# Kowloon Cricket Club = 9
# Krira Shikkha Protisthan Under-14s = 16
# Krira Shikkha Protisthan Under-16s = 18
# Krira Shikkha Protisthan Under-18s = 14
# Kuala Lumpur = 17
# Kunar Province = 21
# Kunar Province Under-16s = 10
# Kunar Province Under-17s = 14
# Kunduz Province = 14
# Kunduz Province Under-16s = 9
# Kunduz Province Under-17s = 18
# Kurunegala = 15
# Kurunegala Combined XI = 4
# Kurunegala District = 1
# Kurunegala Youth Cricket Club = 102
# Kurunegala Youth Cricket Club Women = 23
# Kuwait = 72
# Kuwait Crusaders = 6
# Kuwait Under-16s = 12
# Kuwait Under-17s = 13
# Kuwait Under-19s = 64
# Kuwait Women = 13
# KwaZulu-Natal = 33
# KwaZulu-Natal Academy XI = 2
# KwaZulu-Natal Inland = 30
# KwaZulu-Natal Inland Under-13s = 50
# KwaZulu-Natal Inland Under-15s = 36
# KwaZulu-Natal Inland Under-17s = 35
# KwaZulu-Natal Inland Under-19s = 76
# KwaZulu-Natal Inland Women = 58
# KwaZulu-Natal Under-13s = 47
# KwaZulu-Natal Under-15s = 41
# KwaZulu-Natal Under-17s = 32
# KwaZulu-Natal Under-19s = 30
# KwaZulu-Natal Women = 37
# L Hall's XI = 1
# L to Z = 2
# LC Steven's XI = 5
# LLU Cricket Club = 17
# LUMHS Hyderabad = 24
# Laghman Province = 11
# Laghman Province Under-16s = 15
# Laghman Province Under-17s = 17
# Lahore = 338
# Lahore B = 1
# Lahore Blues = 14
# Lahore City = 1
# Lahore City Whites = 2
# Lahore Division = 74
# Lahore Eagles = 25
# Lahore Education Board = 8
# Lahore Lions = 14
# Lahore Municipal Corporation = 7
# Lahore Qalandars = 13
# Lahore Ravi = 28
# Lahore Region Blues = 1
# Lahore Region Whites = 2
# Lahore Shalimar = 26
# Lahore Under-19s Women = 6
# Lahore Whites = 15
# Lahore Women = 1
# Lahore Women Cricket Association = 3
# Laidley (Lockyear Association) = 1
# Lalitpur Patriots = 2
# Lancashire = 360
# Lancashire 2nd XI = 43
# Lancashire Cricket Board = 27
# Lancashire Women = 7
# Lanka Women's Cricket Club = 20
# Lankan Cricket Club = 25
# Lantau Galaxy Riders = 4
# Larkana Bulls = 6
# Larkana Region = 3
# Lasers Women = 2
# Lashings World XI = 9
# League Cricket Conference = 2
# Leeds Bradford UCCE = 2
# Leeds/Bradford MCCU = 44
# Leeward Islands = 104
# Leeward Islands Under-19s = 9
# Left-Handed = 4
# Leicestershire = 222
# Leicestershire 2nd XI = 51
# Leicestershire Cricket Board = 16
# Leicestershire Women = 22
# Leicestershire XI = 1
# Leinster Lightning = 6
# Leopards = 9
# Leprechauns Cricket Club = 8
# Lesotho = 26
# Lesotho Under-19s = 16
# Lesotho Women = 14
# Limpopo = 19
# Limpopo Under-13s = 49
# Limpopo Under-15s = 34
# Limpopo Under-17s = 33
# Limpopo Under-19s = 25
# Limpopo Women = 60
# Lincolnshire = 87
# Lincolnshire Women = 43
# Lions = 1
# Lions Cubs = 7
# Lions of the Desert = 8
# Liphook & Ripsley = 13
# Liverpool and District = 19
# Logan Village (Beenleigh-Logan Association) = 1
# Logar Province = 6
# Logar Province Under-16s = 13
# Logar Province Under-17s = 16
# Lomas Athletic Club = 5
# London County = 24
# London United = 1
# Lord Brackley's XI = 1
# Lord Hawke's XI = 1
# Lord Sheffield's XI = 3
# Lord Strathavon's XI = 1
# Lord Willingdon's XI = 2
# Loughborough MCCU = 16
# Loughborough MCCU 2nd XI = 2
# Loughborough Marylebone Cricket Club University (England) = 18
# Loughborough UCCE = 1
# Lower Canada = 16
# Lumbini College = 5
# Lumbini Maha Vidyalaya = 13
# Luxembourg = 19
# Lyca Kovai Kings = 17
# Lyceum College = 7
# MA Chidambaram's XI = 1
# MAF Howithzer = 16
# MC Bird's XI = 1
# MCA President's XI = 1
# MECC Cricket Club = 16
# MIA Corporation = 9
# MK Mantri's XI = 1
# MMM College Of Commerce (Pune) = 9
# MN Raiji's XI = 1
# MP Engineer's XI = 1
# MRF XI = 8
# Madhya Pradesh = 225
# Madhya Pradesh Cricket Association XI = 5
# Madhya Pradesh Under-14s = 13
# Madhya Pradesh Under-16s = 15
# Madhya Pradesh Under-19s = 8
# Madhya Pradesh Under-22s = 6
# Madhya Pradesh Women = 11
# Madras = 100
# Madras Cricket Club = 2
# Madras Rubber Factory = 6
# Madurai Super Giant = 15
# Mafatlal Sports Club = 1
# Mahanama College = 1
# Maharaj Kumar of Vizianagram's XI = 3
# Maharaja of Cooch-Behar's XI = 15
# Maharaja of Patiala's XI = 8
# Maharashtra = 269
# Maharashtra Cricket Association XI = 3
# Maharashtra Governor's XI = 1
# Maharashtra Under-16s = 9
# Maharashtra Under-19s = 6
# Maharashtra Under-22s = 3
# Maharashtra Women = 12
# Maharashtra XI = 1
# Mahendranagar United = 2
# Mahinda College = 13
# Mai Dubai = 13
# Maidan Wardak Province = 6
# Maidan Wardak Province Under-16s = 12
# Maidan Wardak Province Under-17s = 17
# Malang 8 = 11
# Malawi = 38
# Malawi Women = 14
# Malaysia = 80
# Malaysia Under-15s = 16
# Malaysia Under-16s = 13
# Malaysia Under-17s = 6
# Malaysia Under-19s = 63
# Malaysia Women = 53
# Malaysian Armed Forces = 16
# Malaysian President's XI = 1
# Malden Wanderers = 7
# Maldives = 21
# Maldives Under-19s = 26
# Maldives Under-21s = 1
# Maldives Under-25s = 1
# Maliyadeva College = 25
# Malnad Gladiators = 13
# Malta = 19
# Mambalam Mosquitos = 8
# Manaus Cricket Club = 17
# Manchester = 25
# Mangalore United = 38
# Manicaland = 24
# Manipur = 34
# Mannar-Vavuniya Combined Schools = 45
# Marians Ladies = 5
# Maris Stella College = 26
# Maritzburg College = 10
# Married = 1
# Marwari College Ranchi = 15
# Marylebone Cricket Club = 624
# Marylebone Cricket Club President's XI = 1
# Marylebone Cricket Club Universities = 9
# Marylebone Cricket Club Women = 2
# Marylebone Cricket Club Women's Invitation XI = 1
# Marylebone Cricket Club Young Cricketers = 30
# Marylebone Cricket Club and Homerton = 1
# Mashonaland = 29
# Mashonaland A = 7
# Mashonaland Country Districts = 14
# Mashonaland Eagles = 16
# Mashonaland Eagles B = 13
# Mashonaland Under-24s = 7
# Masvingo = 1
# Matabeleland = 35
# Matabeleland Invitation XI = 2
# Matabeleland Tuskers = 12
# Matabeleland Tuskers B = 8
# Matale Ladies = 8
# Matara Sports Club = 48
# Matugama Cricket Club = 1
# Medicam Group = 3
# Meghalaya = 18
# Melbourne Cricket Club = 11
# Melbourne Renegades Women = 5
# Melbourne Stars = 1
# Melbourne Stars Women = 2
# Melville = 5
# Menlopark High School = 9
# Mercantile Cricket Association XI = 1
# Metro CC = 9
# Metro Hotel Cricket Team = 9
# Metro Tigers Dubai = 16
# Mexico = 12
# Mexico Women = 13
# Mid West Rhinos = 20
# Mid West Rhinos B = 10
# Mid Western Development Region = 6
# Middlesex = 315
# Middlesex 2nd XI = 41
# Middlesex Cricket Board = 14
# Middlesex Under-17s = 1
# Middlesex Women = 14
# Middlesex XI = 29
# Midland Counties = 1
# Midlands = 23
# Mighty Rhinos = 5
# Minas Gerais Cricket Club = 15
# Minor Associations = 5
# Minor Counties = 72
# Mis Ainak Knights = 5
# Mis Ainak Region = 14
# Mis Ainak Region Under-16s = 2
# Miwand Rangers = 10
# Mizoram = 21
# Modern Plastics = 12
# Mohammedan Sporting Club = 2
# Monaragala Combined = 5
# Montserrat = 11
# Moon Light CC = 9
# Moors Sports Club = 79
# Moratuwa MV = 5
# Moratuwa Sports Club = 77
# Moratuwa Sports Club Women = 24
# Mount Lawley = 1
# Mountaineers = 8
# Mountaineers B = 6
# Mozambique = 40
# Mozambique Under-19s = 14
# Mozambique Women = 12
# Mpumalanga = 19
# Mpumalanga Under-13s = 52
# Mpumalanga Under-15s = 35
# Mpumalanga Under-17s = 31
# Mpumalanga Under-19s = 22
# Mpumalanga Under-19s Women = 7
# Mpumalanga Women = 55
# Multan = 184
# Multan Region = 14
# Multan Tigers = 34
# Multan Under-19s Women = 1
# Mumbai = 203
# Mumbai Champs = 3
# Mumbai Combined XI = 30
# Mumbai Cricket Association President's XI = 1
# Mumbai Cricket Association XI = 6
# Mumbai Indians = 2
# Mumbai Under-16s = 4
# Mumbai Under-17s = 1
# Mumbai Under-19s = 3
# Mumbai Women = 9
# Munster = 1
# Munster Reds = 14
# Murray College Sialkot = 11
# Muslim Commercial Bank = 8
# Muslims = 42
# Mutants = 35
# Muzvezve Tigers = 6
# My Life = 8
# Myanmar = 19
# Myanmar Women = 14
# Mysore = 103
# Mysore Maharaajas = 13
# Mysore Warriors = 4
# Mysuru Warriors = 14
# N to Z = 1
# NIB Management = 15
# Nagaland = 23
# Nagaland Women = 11
# Naik Cricketers = 12
# Naik Riders = 11
# Naik Riders Junior = 16
# Nairobi Buffaloes = 8
# Nalanda College = 16
# Namibia = 63
# Namibia Under-15s = 41
# Namibia Under-19s = 48
# Namibia Women = 29
# Namma Shivamogga = 26
# Nangarhar Province = 7
# Nangarhar Province Under-16s = 18
# Nangarhar Province Under-17s = 16
# Narammala Sports Club Women = 11
# Natal = 282
# Natal (SACB) = 109
# Natal B = 1
# Natal Country Districts = 19
# Natal Under-19s = 1
# Natal XI = 1
# National Bank = 2
# National Bank of Pakistan = 25
# National Cricket Association = 2
# National Recreational Cricket Conference XI Women = 5
# Nawab of Moin-ud-Dowlah XI = 1
# Nawanagar = 13
# Negambo Cricket Club = 22
# Negeri Sembilan = 2
# Negombo Cricket Club = 10
# Nelson = 53
# Nelson Mandela Metropolitan University = 4
# Nelspruit High School = 7
# Nepal = 26
# Nepal Under-16s = 14
# Nepal Under-17s = 4
# Nepal Under-19s = 72
# Nepal Women = 49
# Netherlands = 40
# Netherlands A = 1
# Netherlands Under-15s = 26
# Netherlands Under-17s = 3
# Netherlands Under-19s = 28
# Netherlands Women = 68
# Nevis = 9
# New South Wales = 443
# New South Wales Colts = 7
# New South Wales Country = 34
# New South Wales Invitational XI = 2
# New South Wales Second XI = 10
# New South Wales Second XI Women = 6
# New South Wales Under-15s Women = 7
# New South Wales Under-16s = 6
# New South Wales Under-17s = 10
# New South Wales Under-19s = 21
# New South Wales Under-19s Women = 5
# New South Wales Under-23s = 23
# New South Wales Women = 20
# New York Region = 5
# New Zealand = 21
# New Zealand 2nd XI = 1
# New Zealand A Women = 1
# New Zealand Academy = 1
# New Zealand Air Force = 2
# New Zealand Services = 2
# New Zealand Under-19s = 41
# New Zealand Under-23s = 13
# New Zealand Under-23s Women = 7
# New Zealand Under-25s Women = 1
# New Zealand Women = 20
# New Zealand XI = 3
# New Zealand Young Cricketers = 7
# New Zealanders = 1
# Nice Lead = 19
# Nico International = 17
# Nigeria = 41
# Nigeria Under-19s = 43
# Nigeria Women = 23
# Nile Knights = 5
# Nittabuwa Ladies = 38
# Noida Warriors = 17
# Nomads CC = 4
# Nomads Sports Club = 16
# Nondescripts Cricket Club = 59
# Nooristan Province Under-16s = 18
# Norfolk = 133
# Norfolk Under-17s = 1
# Norfolk Women = 35
# North Central Province Women = 18
# North East Region = 10
# North Eastern Transvaal = 3
# North Holland Hurricanes = 3
# North Island Army = 2
# North Queensland = 3
# North Queensland Under-17s = 8
# North Queensland Under-19s = 7
# North Tasmania = 5
# North Trinidad = 36
# North West = 37
# North West Frontier Province = 39
# North West Frontier Province-Baluchistan = 1
# North West Invitation XI = 2
# North West Region = 10
# North West Under-13s = 49
# North West Under-15s = 36
# North West Under-17s = 31
# North West Under-19s = 48
# North West University = 5
# North West Warriors = 7
# North West Women = 44
# North Western Province = 4
# North Windward Islands Women = 1
# North Zone = 2
# North Zone Women = 1
# North Zone Women (Pakistan) = 9
# North of England = 20
# North of South Africa (SACBOC) = 1
# North-East Combined Ladies = 10
# North-West Warriors = 1
# Northamptonshire = 214
# Northamptonshire 2nd XI = 60
# Northamptonshire Cricket Board = 13
# Northamptonshire Women = 25
# Northern Cape = 2
# Northern Cape High School = 6
# Northern Cape Under-13s = 13
# Northern Cape Under-15s = 8
# Northern Cape Under-17s = 9
# Northern Cape Under-19s = 2
# Northern Cape Women = 7
# Northern Districts = 111
# Northern Districts A = 1
# Northern Districts Second XI = 2
# Northern Districts Under-21s Women = 7
# Northern Districts Women = 38
# Northern Districts XI = 8
# Northern India = 17
# Northern Knights = 13
# Northern New South Wales = 6
# Northern Nomads = 4
# Northern Punjab = 29
# Northern Rhodesia = 6
# Northern Suburbs (Brisbane) = 1
# Northern Territory = 27
# Northern Territory Chief Minister's XI = 7
# Northern Territory Combined Under-15s = 10
# Northern Territory Cricket Association Invitation XI = 6
# Northern Territory Under-17s = 8
# Northern Territory Under-19s = 10
# Northern Transvaal = 15
# Northern Transvaal Country Districts = 8
# Northern Transvaal Country Districts XI = 16
# Northern Transvaal Women = 1
# Northern Windward Islands = 2
# Northerns = 187
# Northerns (Zimbabwe) = 6
# Northerns Academy = 1
# Northerns Invitation XI = 5
# Northerns Under-13s = 46
# Northerns Under-15s = 36
# Northerns Under-17s = 30
# Northerns Under-19s = 37
# Northerns Women = 49
# Northerns XI = 3
# Northumberland = 124
# Northumberland Women = 36
# Norway = 73
# Norway Under-19s = 27
# Nottingham = 1
# Nottinghamshire = 355
# Nottinghamshire 2nd XI = 43
# Nottinghamshire Cricket Board = 17
# Nottinghamshire Premier League = 5
# Nottinghamshire Women = 23
# Nottinghamshire XI = 1
# Nottinghamshire and Leicestershire = 9
# Nugegoda Sports Welfare Club = 8
# OMG = 24
# Odisha = 27
# Odisha Women = 24
# Oil & Natural Gas Corporation = 2
# Old Cambrians Sports Club = 18
# Old D.O.H.S Sports Club = 1
# Old DOHS Sports Club = 17
# Old Etonians = 8
# Old Hararians = 1
# Old Wykehamists = 2
# Oldfield = 3
# Olympia = 1
# Oman = 58
# Oman Avengers = 12
# Oman Development XI = 5
# Oman Under-17s = 12
# Oman Under-19s = 47
# Ontario = 10
# Orange Free State = 305
# Orange Free State Country Districts = 12
# Orient Sporting Club = 20
# Original Team 8 = 13
# Orissa = 221
# Orissa Cricket Association XI = 8
# Orissa Women = 2
# Orleans Club = 2
# Otago = 398
# Otago A = 9
# Otago Invitation XI = 1
# Otago Under-21s Women = 8
# Otago Women = 46
# Oxford MCCU = 28
# Oxford UCCE = 1
# Oxford University = 857
# Oxford University Authentics = 4
# Oxford University Women = 24
# Oxfordshire = 116
# Oxfordshire Women = 24
# P De S Kularatne College = 16
# PCA President's XI = 1
# PCC = 17
# PJ Hindu Gymkhana = 1
# PTCL = 1
# Paarl Boys High School = 17
# Paarl Gymnasium = 8
# Pakhtoon XI = 15
# Pakistan = 17
# Pakistan A = 1
# Pakistan A Women = 4
# Pakistan Air Force = 27
# Pakistan Association of Hong Kong = 16
# Pakistan Automobiles Corporation = 6
# Pakistan B = 1
# Pakistan Cricket Board XI Women = 5
# Pakistan Customs = 49
# Pakistan Education Board = 1
# Pakistan International Airlines = 45
# Pakistan International Airlines B = 2
# Pakistan National Shipping Corporation = 11
# Pakistan Navy = 1
# Pakistan Railways = 65
# Pakistan Security Printing Corporation = 11
# Pakistan Steel = 13
# Pakistan Telecommunication Company Limited = 1
# Pakistan Television = 12
# Pakistan Under-15s = 11
# Pakistan Under-16s = 30
# Pakistan Under-17s = 1
# Pakistan Under-19s = 77
# Pakistan Universities = 19
# Pakistan University Grants Commission = 13
# Pakistan Women = 41
# Pakistan Young Cricketers = 1
# Paktia Province = 23
# Paktia Province Under-16s = 22
# Paktia Province Under-17s = 18
# Paktika Province Under-16s = 22
# Paktika Province Under-17s = 19
# Palace Diamonds = 1
# Palink School of Cricket = 10
# Palink Sports Club = 7
# Palink Sports Club Women = 21
# Pamir Stars = 2
# Panadura Sports Club = 106
# Panama = 32
# Panchakanya Tej = 3
# Papua New Guinea = 59
# Papua New Guinea Under-19s = 91
# Papua New Guinea Women = 38
# Park-N-Shop = 41
# Parkdale United = 1
# Parsees = 73
# Parsees and Muslims = 5
# Partex Sporting Club = 15
# Parwan Province Under-16s = 10
# Parwan Province Under-17s = 17
# Pasha XI = 9
# Payneham = 1
# Payyanur Rockers = 15
# Peace Cricket Club = 16
# Penang = 36
# Pennsylvania University Past and Present = 1
# Perak = 16
# Perth = 1
# Peru = 1
# Peru Women = 10
# Peshawar = 22
# Peshawar Cricket Association = 137
# Peshawar Panthers = 13
# Peshawar Region = 2
# Peshawar University = 13
# Peshawar Zalmi = 1
# Peshawar Zalmi (UAE) = 30
# Peterborough Town CC = 11
# Petersham-Marrickville = 1
# Petworth = 3
# Pharmatarde = 15
# Philadelphians = 70
# Philippines = 23
# Players = 5
# Players CC = 15
# Players of Nottinghamshire = 1
# Players of United States of America = 20
# Players of the North = 1
# Pokhara Rhinos = 1
# Police Sports Club = 86
# Polonnaruwa Combine Schools = 26
# Polonnaruwa District = 1
# Polonnaruwa Ladies = 18
# Port Qasim Authority = 11
# Portsmouth = 4
# Portugal = 26
# Potchefstroom Gimnasium High School = 9
# Prahran Invitation XI = 5
# President's College = 15
# Prestige College = 10
# Pretoria High School Old Boys = 3
# Pretoria University = 19
# Prime Bank Cricket Club = 6
# Prime Doleshwar Sporting Club = 2
# Prime Minister's XI = 6
# Prince of Wales College = 9
# Province Number 1 = 10
# Province Number 2 = 7
# Province Number 3 = 6
# Province Number 4 = 9
# Province Number 5 = 1
# Province Number 6 = 15
# Province Number 7 = 4
# Public Works Department = 29
# Puducherry = 27
# Punjab = 137
# Punjab College Bahawalpur = 13
# Punjab Cricket Association XI = 4
# Punjab Governor's XI (India) = 5
# Punjab Under-14s = 14
# Punjab Under-16s = 10
# Punjab Under-19s = 5
# Punjab Under-22s = 1
# Punjab University = 24
# Punjab University Lahore = 11
# Punjab Women (India) = 16
# Punjab Women Greens = 9
# Punjab Women Whites = 16
# Pushpadana Ladies = 14
# Qalandars = 8
# Qatar = 42
# Qatar Under-19s = 70
# Qld Aboriginal & Torres Strait Islanders = 4
# Queensland = 334
# Queensland Academy of Sport = 11
# Queensland Colts = 7
# Queensland Country = 29
# Queensland Second XI = 2
# Queensland Second XI Women = 4
# Queensland Under-15s = 8
# Queensland Under-15s Women = 8
# Queensland Under-17s = 20
# Queensland Under-19s = 17
# Queensland Under-19s Women = 9
# Queensland Under-23s = 12
# Queensland Women = 43
# Quetta = 105
# Quetta Bears = 39
# Quetta Gladiators = 1
# Quetta Region = 14
# Quick Haag = 7
# R Leigh's XI = 3
# RA Bennett's XI = 1
# RAK Bullet = 13
# RCA Centre of Excellence = 1
# RH Powel's XI = 4
# RK Mody XI = 2
# RS Grant XI = 1
# RS Lucas' XI = 2
# Ragama Cricket Club = 29
# Raging Bulls = 9
# Railway Sports Club = 3
# Railway Sports Promotion Board XI = 7
# Railways = 148
# Railways (India) Women = 7
# Railways Under-19s = 2
# Rainbow = 7
# Raja of Jath's XI = 1
# Rajasthan = 189
# Rajasthan Cricket Association President's XI = 2
# Rajasthan Cricket Association XI = 13
# Rajasthan Royals = 1
# Rajasthan Under-14s = 11
# Rajasthan Under-16s = 15
# Rajasthan Under-19s = 4
# Rajasthan Women = 15
# Rajputana = 42
# Rajputana and Central India = 2
# Rajshahi = 2
# Rajshahi Division = 44
# Rajshahi Division Under-14s = 15
# Rajshahi Division Under-16s = 17
# Rajshahi Division Under-18s = 15
# Rajshahi Division Women = 1
# Ram Lal Anand College (Delhi) = 15
# Ramsbottom = 2
# Randwick-Petersham = 6
# Rangers = 9
# Rangoon Gymkhana = 4
# Rangpur Division = 14
# Rangpur Division Under-14s = 14
# Rangpur Division Under-16s = 18
# Rangpur Division Under-18s = 18
# Rapid Foundation = 15
# Ratnagiri Riders Cricket = 13
# Rawalpindi = 175
# Rawalpindi Rams = 18
# Rawalpindi Region = 1
# Red Knights = 24
# Redco Pakistan Ltd = 3
# Reivers = 7
# Renegades = 25
# Rest (Bombay Tournament) = 23
# Rest of Australia = 2
# Rest of Baluchistan = 14
# Rest of England = 1
# Rest of Leeward Islands = 1
# Rest of New Zealand = 1
# Rest of North West Frontier Province = 7
# Rest of Pakistan Under-19s = 3
# Rest of Punjab = 8
# Rest of SACB = 1
# Rest of Sindh = 14
# Rest of South Africa = 2
# Rest of Windward Islands = 1
# Rest of the World XI = 1
# Rhodesia = 161
# Richmond College = 14
# Rift Valley Rhinos = 9
# Ringwood = 1
# Rio Sports Club = 30
# Rising Challengers = 10
# Rising Pune Supergiant = 1
# Rising Pune Supergiants = 1
# Rising Stars = 6
# Rising Stars Chuis = 3
# Rising Stars Udyavar = 14
# Rising Zebras = 3
# Rizvi Mumbai = 14
# Roaring Lions = 6
# Rocking Stars = 16
# Rockingham-Mandurah Invitational XI = 3
# Rockstars = 33
# Rohtek Eleven = 8
# Rondebosch Boys High School = 1
# Rood en Wit = 5
# Rood en Wit Women = 3
# Roshanara Club = 4
# Rowlin Cricket Academy = 11
# Royal Air Force = 30
# Royal College = 49
# Royal College Panadura = 4
# Royal Elephants = 3
# Royal Institute = 8
# Royal Institute of Colombo = 14
# Royal Navy = 56
# Royals = 1
# Rubies = 2
# Ruby Kanchi Warriors = 1
# Ruby Trichy Warriors = 9
# Rupandehi Challengers = 9
# Rwanda = 29
# Rwanda Under-19s = 15
# Rwanda Women = 25
# Rwenzori Warriors = 12
# S.Thomas' College = 8
# S.Thomas' College Bandarawela = 17
# S.Thomas' College Matale = 5
# SAI Technology & Medicine = 15
# SFS = 13
# SGH Challengers = 9
# SGH Warriors = 8
# SHJ Warriors = 11
# SIB Warriors = 16
# SLI Information Technology = 15
# SOL Group = 20
# SP Warriors = 11
# SRM University (Chennai) = 9
# SS Lootah Spinners = 15
# Sagarmatha Legends = 1
# Saints Sports Club = 1
# Samoa = 29
# Samoa Under-19s = 28
# Samoa Women = 18
# Sandhurst = 22
# Sandpipers = 13
# Sao Paulo Cricket Club = 12
# Sapphires = 4
# Saracens = 13
# Saracens Sports Club = 33
# Sarawak = 18
# Sargoda Multan and Bahawalpur Combined XI = 1
# Sargodha = 155
# Saudi Arabia = 89
# Saudi Arabia Under-16s = 13
# Saudi Arabia Under-19s = 71
# Saurashtra = 170
# Saurashtra Cricket Association XI = 2
# Saurashtra Under-16s = 6
# Saurashtra Under-19s = 4
# Saurashtra Women = 12
# Scarborough = 1
# Schools Invitation XI = 2
# Scorpions = 30
# Scotland = 307
# Scotland A = 5
# Scotland A Women = 4
# Scotland Under-15s = 17
# Scotland Under-17s = 1
# Scotland Under-19s = 52
# Scotland Women = 43
# Scottish Universities = 1
# Sealine Taha CC = 14
# Sebastianites Cricket and Athletic Club = 63
# Sedbergh School = 6
# Seeduwa Raddoluwa Cricket Club = 39
# Selangor = 20
# Selborne College = 4
# Service Industries = 20
# Services = 249
# Services (Pakistan) = 42
# Seychelles = 15
# Shagarah Panthers = 21
# Shaheed Jewel XI = 1
# Shaheed Mushtaque XI = 1
# Shaheen Cricket Club = 18
# Shakthi Ladies = 42
# Shamanoor Davangere Diamonds = 21
# Shardashram Vidyamandir High School = 6
# Sheffield = 27
# Sheffield Collegiate CC = 5
# Sheffield and Leicester = 6
# Sheikh Jamal Cricketers = 17
# Sheikh Jamal Dhanmondi Club = 9
# Sheikhpura District Women Cricket Association = 1
# Sheikhupura = 11
# Sheikhupura Cricket Association = 31
# Shinepukur Cricket Club = 1
# Shropshire = 100
# Shropshire Women = 33
# Sialkot = 14
# Sialkot CC = 9
# Sialkot Cricket Association = 22
# Sialkot Region = 6
# Sialkot Stallions = 19
# Siechem Madurai Panthers = 5
# Sierra Leone = 23
# Sierra Leone Under-19s = 31
# Sierra Leone Women = 12
# Sikhs = 14
# Sikkim = 24
# Sikkim Under-16s = 15
# Sileby Town Ladies CC = 10
# Sind = 55
# Sind University = 16
# Singapore = 105
# Singapore CA Presidents's XI = 15
# Singapore Cricket Club = 14
# Singapore Under-16s = 10
# Singapore Under-17s = 9
# Singapore Under-19s = 21
# Singapore Women = 34
# Singer Sri Lanka Ltd = 9
# Singha Sports Club = 89
# Singham CC = 8
# Single = 4
# Sinhalese Sports Club = 65
# Sir H Mann's XI = 4
# Sir Homi Mehta's XI = 4
# Sir J Cahn's XI = 3
# Sir Joseph Kay's XI = 3
# Sir L Parkinson's XI = 1
# Sir PF Warner's XI = 2
# Sir TEW Brinckman's XI = 3
# Slimline Sport Club = 5
# Slimline Sport Club Women = 6
# Slovenia = 17
# Slow Bowlers = 1
# Somerset = 317
# Somerset 2nd XI = 34
# Somerset Cricket Board = 18
# Somerset Women = 20
# South Africa = 18
# South Africa African XI = 14
# South Africa Air Force = 1
# ...
# ['Western Australia,', 'Western Australia Under-17s,', 'Western Australia Under-19s'] = 1
# ['Western Australia,', 'Western Australia Under-17s,', 'Western Australia Under-23s'] = 1
# ['Western Australia,', 'Western Australia Under-23s'] = 2
# ['Western Australia,', 'Western Australia XI'] = 1
# ['Western Australia,', 'Worcestershire'] = 1
# ['Western Cape Invitation XI,', 'Western Province Under-19s'] = 4
# ['Western Cape Invitation XI,', 'Western Province Under-19s,', "Wynberg Boys' High School"] = 1
# ['Western Province North,', 'Western Province Suburbs'] = 1
# ['Western Province Under-13s,', 'Western Province Under-15s'] = 2
# ['Western Province Under-17s,', "Wynberg Boys' High School"] = 1
# ['Western Province Under-19s,', "Wynberg Boys' High School"] = 2
# ['Western Province,', 'Western Province (SACB),', 'Western Province B'] = 1
# ['Western Province,', 'Western Province Academy'] = 1
# ['Western Province,', 'Western Province B'] = 1
# ['Western Province,', 'Western Province South'] = 1
# ['Western Province,', 'Western Province Under-19s'] = 9
# ['Wiltshire,', 'Wiltshire Under-13s,', 'Wiltshire Under-14s,', 'Wiltshire Under-15s,', 'Wiltshire Under-17s'] = 1
# ['Wiltshire,', 'Worcestershire 2nd XI'] = 3
# ['Wiltshire,', 'Worcestershire'] = 1
# ['Wiltshire,', 'Worcestershire,', 'Worcestershire 2nd XI'] = 1
# ['Windward Islands,', 'Windward Islands Under-19s'] = 2
# ['Worcestershire 2nd XI,', 'Worcestershire Academy,', 'Worcestershire Under-13s,', 'Worcestershire Under-14s,', 'Worcestershire Under-15s,', 'Worcestershire Under-17s'] = 2
# ['Worcestershire 2nd XI,', 'Worcestershire Under-13s,', 'Worcestershire Under-14s,', 'Worcestershire Under-15s,', 'Worcestershire Under-17s'] = 2
# ['Worcestershire 2nd XI,', 'Worcestershire Under-13s,', 'Worcestershire Under-14s,', 'Worcestershire Under-15s,', 'Worcestershire Under-17s,', 'Worcestershire Under-19s'] = 1
# ['Worcestershire 2nd XI,', 'Worcestershire Under-13s,', 'Worcestershire Under-15s,', 'Worcestershire Under-17s,', 'Worcestershire Under-19s'] = 1
# ['Worcestershire 2nd XI,', 'Worcestershire Under-13s,', 'Worcestershire Under-17s'] = 1
# ['Worcestershire Under-15s,', 'Worcestershire Under-17s'] = 1
# ['Worcestershire,', 'Worcestershire 2nd XI'] = 6
# ['Worcestershire,', 'Worcestershire 2nd XI,', 'Worcestershire Under-13s,', 'Worcestershire Under-14s,', 'Worcestershire Under-15s,', 'Worcestershire Under-17s'] = 1
# ['Worcestershire,', 'Worcestershire Cricket Board'] = 2
# ['Worcestershire,', 'Yorkshire'] = 5
# ['Worcestershire,', 'Zimbabwe Cricket Academy'] = 1
# ['Worcestershire,', 'Zimbabwe Under-19s'] = 1
# ['Yorkshire 2nd XI,', 'Yorkshire Academy'] = 2
# ['Yorkshire 2nd XI,', 'Yorkshire Academy,', 'Yorkshire Under-13s,', 'Yorkshire Under-14s,', 'Yorkshire Under-15s,', 'Yorkshire Under-17s'] = 3
# ['Yorkshire 2nd XI,', 'Yorkshire Academy,', 'Yorkshire Under-13s,', 'Yorkshire Under-15s'] = 1
# ['Yorkshire 2nd XI,', 'Yorkshire Academy,', 'Yorkshire Under-14s,', 'Yorkshire Under-15s'] = 1
# ['Yorkshire 2nd XI,', 'Yorkshire Academy,', 'Yorkshire Under-14s,', 'Yorkshire Under-15s,', 'Yorkshire Under-17s'] = 1
# ['Yorkshire 2nd XI,', 'Yorkshire Academy,', 'Yorkshire Under-15s,', 'Yorkshire Under-17s'] = 1
# ['Yorkshire 2nd XI,', 'Yorkshire Academy,', 'Yorkshire Under-17s'] = 2
# ['Yorkshire 2nd XI,', 'Yorkshire Under-13s,', 'Yorkshire Under-14s,', 'Yorkshire Under-15s,', 'Yorkshire Under-17s'] = 1
# ['Yorkshire 2nd XI,', 'Yorkshire Under-17s'] = 1
# ['Yorkshire 2nd XI,', 'Yorkshire Under-17s,', 'Yorkshire Under-19s'] = 1
# ['Yorkshire,', 'Yorkshire 2nd XI'] = 3
# ['Yorkshire,', 'Yorkshire 2nd XI,', 'Yorkshire Academy,', 'Yorkshire Under-13s,', 'Yorkshire Under-14s,', 'Yorkshire Under-15s'] = 1
# ['Yorkshire,', 'Yorkshire 2nd XI,', 'Yorkshire Academy,', 'Yorkshire Under-13s,', 'Yorkshire Under-14s,', 'Yorkshire Under-15s,', 'Yorkshire Under-17s'] = 1
# ['Yorkshire,', 'Yorkshire 2nd XI,', 'Yorkshire Academy,', 'Yorkshire Under-14s,', 'Yorkshire Under-15s,', 'Yorkshire Under-17s'] = 2
# ['Yorkshire,', 'Yorkshire 2nd XI,', 'Yorkshire Academy,', 'Yorkshire Under-15s,', 'Yorkshire Under-17s'] = 1
# ['Yorkshire,', 'Yorkshire 2nd XI,', 'Yorkshire Academy,', 'Yorkshire Under-17s'] = 1
# ['Yorkshire,', 'Yorkshire 2nd XI,', 'Yorkshire Cricket Board'] = 1
# ['Yorkshire,', 'Yorkshire 2nd XI,', 'Yorkshire Under-15s,', 'Yorkshire Under-17s'] = 1
# ['Yorkshire,', 'Yorkshire Cricket Board'] = 6
# ['Zambia,', 'Zambia Under-19s'] = 10
# ['Zimbabwe A,', 'Zimbabwe Under-19s'] = 1
# ['Zimbabwe Cricket Academy,', 'Zimbabwe Under-19s'] = 1
# ['Zimbabwe Cubs,', 'Zimbabwe Under-17s,', 'Zimbabwe Under-19s'] = 3
# ['Zimbabwe Cubs,', 'Zimbabwe Under-19s'] = 2
# ['Zimbabwe Under-13s,', 'Zimbabwe Under-19s'] = 7
# ['Zimbabwe Under-15s,', 'Zimbabwe Under-18s,', 'Zimbabwe Under-19s'] = 1
# ['Zimbabwe Under-17s,', 'Zimbabwe Under-19s'] = 5
# ['Zimbabwe,', 'Africa XI,', 'Ahmedabad Rockets,', 'Hampshire,', 'Matabeleland,', 'Warwickshire'] = 1
# ['Zimbabwe,', 'Africa XI,', 'Barbados Tridents,', 'Mashonaland A,', 'Mashonaland Eagles,', 'Northamptonshire,', 'Northerns (Zimbabwe),', 'Quetta Gladiators,', 'Sheikh Jamal Dhanmondi Club,', 'Southern Rocks,', 'Sylhet Royals,', 'Zimbabwe Under-19s,', 'Zimbabwe XI'] = 1
# ['Zimbabwe,', 'Africa XI,', 'Centrals,', 'Mid West Rhinos,', 'Midlands,', 'Zimbabwe A,', 'Zimbabwe Provinces'] = 1
# ['Zimbabwe,', 'Africa XI,', 'Matabeleland,', 'Matabeleland Tuskers,', 'Westerns,', 'Zimbabwe Cricket Academy,', 'Zimbabwe XI'] = 1
# ['Zimbabwe,', 'Africa XI,', 'Matabeleland,', 'Matabeleland Tuskers,', 'Westerns,', 'Zimbabwe Select XI'] = 1
# ['Zimbabwe,', 'Africa XI,', 'Mid West Rhinos,', 'Zimbabwe A,', 'Zimbabwe Cricket Academy,', 'Zimbabwe XI'] = 1
# ['Zimbabwe,', 'Boland,', 'Gloucestershire,', 'Natal,', 'Northamptonshire'] = 1
# ['Zimbabwe,', 'Boland,', 'Mashonaland,', 'Mashonaland A,', 'Warwickshire'] = 1
# ['Zimbabwe,', 'Brendan Taylor XI,', 'Mashonaland Eagles,', 'Mountaineers,', "Zimbabwe President's XI,", 'Zimbabwe Under-19s'] = 1
# ['Zimbabwe,', 'Brothers Union,', 'Duronto Rajshahi,', 'Hampshire,', 'Midlands,', 'Quetta Gladiators,', 'Southern Rocks,', 'Western Australia'] = 1
# ['Zimbabwe,', 'Brothers Union,', 'Matabeleland,', 'Matabeleland Tuskers,', 'Zimbabwe A,', 'Zimbabwe Board XI,', 'Zimbabwe Provinces,', 'Zimbabwe Select XI,', 'Zimbabwe Under-19s,', 'Zimbabwe XI'] = 1
# ['Zimbabwe,', 'Cambridge University,', 'Manicaland,', 'Matabeleland'] = 1
# ['Zimbabwe,', 'Central Districts,', 'Lancashire,', 'Lancashire 2nd XI,', 'Mashonaland Eagles,', 'Zimbabwe Under-19s,', 'Zimbabwe XI'] = 1
# ['Zimbabwe,', 'Centrals,', 'Dhaka Dynamites,', 'Mashonaland,', 'Mid West Rhinos,', 'Zimbabwe A'] = 1
# ['Zimbabwe,', 'Centrals,', 'Manicaland,', 'Manicaland A,', 'Mashonaland,', 'Southern Rocks,', 'Southerns,', "Zimbabwe Board President's XI,", 'Zimbabwe Cricket Academy,', 'Zimbabwe Select XI,', 'Zimbabwe XI'] = 1
# ['Zimbabwe,', 'Centrals,', 'Mashonaland Eagles,', 'Mid West Rhinos,', 'Southern Rocks,', 'Zimbabwe A,', 'Zimbabwe Provinces,', 'Zimbabwe Under-19s'] = 1
# ['Zimbabwe,', 'Centrals,', 'Mashonaland,', 'Southern Rocks,', 'Southerns,', 'Zimbabwe A'] = 1
# ['Zimbabwe,', 'Centrals,', 'Masvingo,', 'Mid West Rhinos,', 'Southern Rocks,', 'Southerns,', 'Speen Ghar Tigers,', 'Zimbabwe A,', 'Zimbabwe Under-19s'] = 1
# ['Zimbabwe,', 'Centrals,', 'Masvingo,', 'Mountaineers,', 'Southern Rocks,', 'Southerns,', 'Zimbabwe A'] = 1
# ['Zimbabwe,', 'Centrals,', 'Matabeleland Tuskers,', 'Southern Rocks,', 'Southerns,', 'Westerns'] = 1
# ['Zimbabwe,', 'Centrals,', 'Melbourne Renegades,', 'Mid West Rhinos,', 'Zimbabwe Under-19s'] = 1
# ['Zimbabwe,', 'Centrals,', 'Mid West Rhinos,', 'Midlands,', 'Southern Rocks,', 'Zimbabwe A'] = 1
# ['Zimbabwe,', 'Centrals,', 'Mid West Rhinos,', 'Midlands,', 'Zimbabwe A,', 'Zimbabwe Provinces,', 'Zimbabwe XI'] = 1
# ['Zimbabwe,', 'Centrals,', 'Mountaineers,', 'Southern Rocks,', 'Southern Rocks B,', 'Zimbabwe Under-19s'] = 1
# ['Zimbabwe,', 'Cheshire,', 'Essex,', 'Essex 2nd XI,', 'Leicestershire,', 'Marylebone Cricket Club,', 'Mashonaland,', 'Mashonaland A,', 'Mashonaland Eagles,', 'Mashonaland Under-24s,', 'Young Mashonaland'] = 1
# ['Zimbabwe,', 'Chittagong Kings,', 'Lahore Qalandars,', 'Mashonaland A,', 'Mid West Rhinos,', 'Nottinghamshire,', 'Prime Bank Cricket Club,', 'Sunrisers Hyderabad,', 'Wellington,', 'Zimbabwe A,', 'Zimbabwe Under-19s,', 'Zimbabwe XI'] = 1
# ['Zimbabwe,', 'Chittagong Vikings,', 'Karachi Kings,', 'Lahore Whites,', 'Mashonaland Eagles,', 'Mis Ainak Knights,', 'Montreal Tigers,', 'Northerns (Zimbabwe),', 'Paktia Panthers,', 'Southern Rocks,', 'Tshwane Spartans,', 'Zimbabwe A,', 'Zimbabwe High Performance XI'] = 1
# ['Zimbabwe,', 'Derbyshire,', 'Derbyshire 2nd XI,', 'Midlands,', 'Zimbabwe Cricket Academy'] = 1
# ['Zimbabwe,', 'Eastern Province,', 'Matabeleland'] = 1
# ['Zimbabwe,', 'Easterns (Zimbabwe),', 'Kalabagan Cricket Academy,', 'Manicaland,', 'Mashonaland,', 'Mountaineers,', 'Sylhet Royals,', 'Zimbabwe XI'] = 1
# ['Zimbabwe,', 'Easterns (Zimbabwe),', 'Manicaland,', 'Mashonaland Eagles,', 'Mountaineers,', 'Zimbabwe Cricket Academy'] = 1
# ['Zimbabwe,', 'Easterns (Zimbabwe),', 'Manicaland,', 'Mountaineers'] = 1
# ['Zimbabwe,', 'Easterns (Zimbabwe),', 'Manicaland,', 'Mountaineers,', 'Zimbabwe A,', 'Zimbabwe Under-19s'] = 1
# ['Zimbabwe,', 'Easterns (Zimbabwe),', 'Mashonaland A,', 'Mashonaland Eagles,', 'Mountaineers,', 'Zimbabwe A,', 'Zimbabwe Board XI,', 'Zimbabwe Select XI,', 'Zimbabwe Under-19s,', 'Zimbabwe XI'] = 1
# ['Zimbabwe,', 'Easterns (Zimbabwe),', 'Mashonaland,', 'Mashonaland Eagles,', 'Mountaineers,', 'Zimbabwe A,', 'Zimbabwe XI'] = 1
# ['Zimbabwe,', 'Easterns (Zimbabwe),', 'Mountaineers'] = 1
# ['Zimbabwe,', 'Easterns (Zimbabwe),', 'Mountaineers,', 'Zimbabwe A,', 'Zimbabwe Under-19s,', 'Zimbabwe XI'] = 1
# ['Zimbabwe,', 'Easterns (Zimbabwe),', 'Mountaineers,', 'Zimbabwe Select XI'] = 1
# ['Zimbabwe,', 'Elite International Cricket Academy,', 'Mashonaland Eagles,', 'Zimbabwe A,', "Zimbabwe Chairman's XI,", 'Zimbabwe Under-19s'] = 1
# ['Zimbabwe,', 'Essex,', 'Marylebone Cricket Club,', 'Mashonaland,', 'South Australia'] = 1
# ['Zimbabwe,', 'Gloucestershire,', 'Gloucestershire 2nd XI,', 'Leicestershire,', 'Leicestershire 2nd XI,', 'Midlands,', 'Southern Rocks'] = 1
# ['Zimbabwe,', 'Hampshire,', 'Hampshire 2nd XI,', 'Mashonaland A,', 'Mashonaland Eagles,', 'Zimbabwe Cricket Academy'] = 1
# ['Zimbabwe,', 'Kent,', 'Manicaland,', 'Marylebone Cricket Club,', 'Mashonaland,', 'Mashonaland Country Districts,', 'Nottinghamshire,', 'Zimbabwe Cricket Academy'] = 1
# ['Zimbabwe,', 'Leicestershire 2nd XI,', 'Mashonaland,', 'Mashonaland Country Districts'] = 1
# ['Zimbabwe,', 'Manicaland'] = 2
# ['Zimbabwe,', 'Manicaland,', 'Mashonaland'] = 1
# ['Zimbabwe,', 'Manicaland,', 'Mashonaland,', 'Mashonaland A,', 'Mashonaland Under-24s,', 'Young Mashonaland'] = 1
# ['Zimbabwe,', 'Manicaland,', 'Mashonaland,', 'Mashonaland Country Districts'] = 1
# ['Zimbabwe,', 'Manicaland,', 'Mashonaland,', 'Matabeleland'] = 1
# ['Zimbabwe,', 'Manicaland,', 'Matabeleland,', 'Zimbabwe Cricket Academy'] = 1
# ['Zimbabwe,', 'Manicaland,', 'Mountaineers,', 'Mountaineers,', 'Southern Rocks,', 'Zimbabwe Under-19s'] = 1
# ['Zimbabwe,', 'Manicaland,', 'Zimbabwe Cricket Academy'] = 1
# ['Zimbabwe,', 'Marylebone Cricket Club,', 'Mashonaland Eagles,', 'Mid West Rhinos,', 'Northerns (Zimbabwe),', 'Surrey 2nd XI,', 'Zimbabwe A,', "Zimbabwe Chairman's XI,", "Zimbabwe President's XI,", 'Zimbabwe Under-19s'] = 1
# ['Zimbabwe,', 'Mashonaland A,', 'Matabeleland,', 'Matabeleland Tuskers,', 'Mid West Rhinos,', 'Mountaineers,', 'Southern Rocks,', 'Westerns'] = 1
# ['Zimbabwe,', 'Mashonaland A,', 'Midlands'] = 1
# ['Zimbabwe,', 'Mashonaland Country Districts'] = 4
# ['Zimbabwe,', 'Mashonaland Country Districts,', 'Mashonaland Eagles,', 'Midlands,', 'Mumbai Indians,', 'Northerns (Zimbabwe),', 'Worcestershire,', 'Zimbabwe XI'] = 1
# ['Zimbabwe,', 'Mashonaland Eagles,', 'Northerns (Zimbabwe),', 'Southern Rocks,', 'Zimbabwe Under-19s'] = 1
# ['Zimbabwe,', 'Mashonaland Eagles,', 'Northerns (Zimbabwe),', 'Zimbabwe A,', 'Zimbabwe Under-19s,', 'Zimbabwe XI'] = 1
# ['Zimbabwe,', 'Mashonaland Eagles,', 'Northerns (Zimbabwe),', 'Zimbabwe Under-19s'] = 1
# ['Zimbabwe,', 'Mashonaland'] = 9
# ['Zimbabwe,', 'Mashonaland,', 'Mashonaland A'] = 2
# ['Zimbabwe,', 'Mashonaland,', 'Mashonaland A,', 'Mashonaland Under-24s'] = 1
# ['Zimbabwe,', 'Mashonaland,', 'Mashonaland A,', 'Mashonaland Under-24s,', 'Matabeleland Invitation XI,', 'Midlands,', 'Young Mashonaland'] = 1
# ['Zimbabwe,', 'Mashonaland,', 'Mashonaland A,', 'Mashonaland Under-24s,', 'Young Mashonaland'] = 2
# ['Zimbabwe,', 'Mashonaland,', 'Mashonaland A,', 'Matabeleland'] = 2
# ['Zimbabwe,', 'Mashonaland,', 'Mashonaland A,', 'Matabeleland,', 'Matabeleland Tuskers'] = 1
# ['Zimbabwe,', 'Mashonaland,', 'Mashonaland A,', 'Southern Rocks,', 'Zimbabwe Cricket Academy'] = 1
# ['Zimbabwe,', 'Mashonaland,', 'Mashonaland A,', 'Western Province,', 'Young Mashonaland'] = 1
# ['Zimbabwe,', 'Mashonaland,', 'Mashonaland Country Districts'] = 5
# ['Zimbabwe,', 'Mashonaland,', 'Mashonaland Country Districts,', 'Mashonaland Under-24s,', 'Matabeleland'] = 1
# ['Zimbabwe,', 'Mashonaland,', 'Mashonaland Country Districts,', 'Mashonaland Under-24s,', 'Matabeleland,', 'Midlands,', 'Young Mashonaland'] = 1
# ['Zimbabwe,', 'Mashonaland,', 'Mashonaland Eagles,', 'Northerns (Zimbabwe),', 'Zimbabwe A'] = 1
# ['Zimbabwe,', 'Mashonaland,', 'Mashonaland Eagles,', 'Zimbabwe Cricket Academy'] = 1
# ['Zimbabwe,', 'Mashonaland,', 'Mashonaland Eagles,', 'Zimbabwe Under-19s'] = 1
# ['Zimbabwe,', 'Mashonaland,', 'Mashonaland Under-24s'] = 1
# ['Zimbabwe,', 'Mashonaland,', 'Mashonaland Under-24s,', 'Southern Rocks,', 'Young Mashonaland'] = 1
# ['Zimbabwe,', 'Mashonaland,', 'Matabeleland'] = 2
# ['Zimbabwe,', 'Mashonaland,', 'Matabeleland,', 'Matabeleland Tuskers,', 'Westerns,', 'Zimbabwe XI'] = 1
# ['Zimbabwe,', 'Mashonaland,', 'Tasmania'] = 1
# ['Zimbabwe,', 'Mashonaland,', 'Zimbabwe Cricket Academy'] = 1
# ['Zimbabwe,', 'Masvingo,', 'Southern Rocks,', 'Southerns,', 'Zimbabwe A,', 'Zimbabwe XI'] = 1
# ['Zimbabwe,', 'Matabeleland Tuskers,', 'Matabeleland Tuskers B,', 'Zimbabwe Under-19s'] = 1
# ['Zimbabwe,', 'Matabeleland Tuskers,', 'Midlands,', 'Southern Rocks,', 'Zimbabwe A,', 'Zimbabwe Under-19s,', 'Zimbabwe XI'] = 1
# ['Zimbabwe,', 'Matabeleland Tuskers,', 'Midlands,', 'Zimbabwe Cricket Academy'] = 1
# ['Zimbabwe,', 'Matabeleland Tuskers,', 'Southern Rocks,', 'Zimbabwe A,', "Zimbabwe President's XI,", 'Zimbabwe Under-17s,', 'Zimbabwe Under-19s'] = 1
# ['Zimbabwe,', 'Matabeleland Tuskers,', 'Westerns,', 'Zimbabwe A,', 'Zimbabwe Provinces,', 'Zimbabwe Under-19s,', 'Zimbabwe XI'] = 1
# ['Zimbabwe,', 'Matabeleland'] = 4
# ['Zimbabwe,', 'Matabeleland,', 'Matabeleland Tuskers,', 'Westerns,', 'Zimbabwe A'] = 1
# ['Zimbabwe,', 'Matabeleland,', 'Matabeleland Tuskers,', 'Westerns,', 'Zimbabwe Cricket Academy'] = 1
# ['Zimbabwe,', 'Matabeleland,', 'Matabeleland Tuskers,', 'Westerns,', 'Zimbabwe Under-23s'] = 1
# ['Zimbabwe,', 'Matabeleland,', 'Matabeleland Tuskers,', 'Zimbabwe Under-19s'] = 1
# ['Zimbabwe,', 'Matabeleland,', 'Mid West Rhinos'] = 1
# ['Zimbabwe,', 'Mid West Rhinos,', 'Mid West Rhinos B,', 'Zimbabwe A'] = 1
# ['Zimbabwe,', 'Mid West Rhinos,', 'Northerns (Zimbabwe),', 'Zimbabwe A,', 'Zimbabwe Board XI,', 'Zimbabwe Select XI,', 'Zimbabwe Under-19s'] = 1
# ['Zimbabwe,', 'Mid West Rhinos,', 'Zimbabwe Under-17s'] = 1
# ['Zimbabwe,', 'Mid West Rhinos,', 'Zimbabwe Under-19s'] = 2
# ['Zimbabwe,', 'Midlands'] = 1
# ['Zimbabwe,', 'Midlands,', 'North West,', 'Zimbabwe Under-19s'] = 1
# ['Zimbabwe,', 'Mountaineers,', 'Zimbabwe A,', 'Zimbabwe Under-19s,', 'Zimbabwe XI'] = 1
# ['Zimbabwe,', 'Mountaineers,', 'Zimbabwe Cubs,', 'Zimbabwe Under-19s'] = 1
# ['Zimbabwe,', 'Mountaineers,', 'Zimbabwe Under-19s'] = 2
# ['Zimbabwe,', 'Natal,', 'Suffolk'] = 1
# ['Zimbabwe,', 'Shropshire'] = 1
# ['Zimbabwe,', 'Southerns'] = 1
# ['Zimbabwe,', 'Western Transvaal'] = 1
# ['Zimbabwe,', 'Zimbabwe Under-13s,', 'Zimbabwe Under-17s,', 'Zimbabwe Under-19s'] = 1
# ['Zimbabwe,', 'Zimbabwe Under-13s,', 'Zimbabwe Under-18s,', 'Zimbabwe Under-19s'] = 1
# ['Zimbabwe,', 'Zimbabwe Under-17s,', 'Zimbabwe Under-19s'] = 2
# ['Zimbabwe,', 'Zimbabwe Under-19s'] = 2
# ['Zimbabwe-Rhodesia,', 'Kent,', 'Surrey'] = 1

# %%
# List of teams needed
teams = ["India",
        "Australia",
        "South Africa",
        "New Zealand",
        "Sri Lanka",
        "England",
        "Pakistan",
        "West Indies",
        "Bangladesh",
        "Zimbawbe",
        "Afghanistan",
        "Ireland",
        "Scotland",
        "Hong Kong",
        "Kenya",
        "Oman",
        "India Under-19s",
        "Australia Under-19s",
        "South Africa Under-19s",
        "New Zealand Under-19s",
        "Sri Lanka Under-19s",
        "England Under-19s",
        "Pakistan Under-19s",
        "West Indies Under-19s",
        "Bangladesh Under-19s",
        "Zimbawbe Under-19s",
        "Afghanistan Under-19s",
        "Ireland Under-19s",
        "Scotland Under-19s",
        "Hong Kong Under-19s",
        "Kenya Under-19s",
        "Oman Under-19s",
        "India Women",
        "Australia Women",
        "South Africa Women",
        "New Zealand Women",
        "Sri Lanka Women",
        "England Women",
        "Pakistan Women",
        "West Indies Women",
        "Bangladesh Women",
        "Zimbawbe Women",
        "Afghanistan Women",
        "Ireland Women",
        "Scotland Women",
        "Hong Kong Women",
        "Kenya Women",
        "Oman Women"]

# %%
df = df.loc[df["Major teams"].isin(teams)]

# %%
df.shape
# Out:
# (2304, 41)

# %%
df.groupby("Playing role")["Playing role"].count()
# Out:
# Playing role
# -                       2150
# Allrounder                31
# Batsman                   18
# Bowler                    52
# Bowling allrounder         2
# Middle-order batsman      11
# Opening batsman           13
# Top-order batsman          7
# Wicketkeeper              11
# Wicketkeeper batsman       9
# Name: Playing role, dtype: int64

# %%
# People with only bowling records in ODI
df.loc[((df["BATTING_ODIs_Runs"] == "-") | (df["BATTING_ODIs_Runs"] == 0)) & ((df["BOWLING_ODIs_Balls"] != "-") | (df["BOWLING_ODIs_Balls"] != 0))].shape
# Out:
# (2007, 41)

# %%
# People with only batting records in ODI
df.loc[((df["BATTING_ODIs_Runs"] != "-") | (df["BATTING_ODIs_Runs"] != 0)) & ((df["BOWLING_ODIs_Balls"] == "-") | (df["BOWLING_ODIs_Balls"] == 0))].shape
# Out:
# (2104, 41)

# %%
df["Died"].head(20)
# Out:
# 23                                                     -
# 30                                                     -
# 34                                                     -
# 41                                                     -
# 218                                                    -
# 332                                                    -
# 334                                                    -
# 335                                                    -
# 336                                                    -
# 337                                                    -
# 338                                                    -
# 347                                                    -
# 493                                                    -
# 523                                                    -
# 627                                                    -
# 676                                                    -
# 688                                                    -
# 722    June 2, 1853, Tortworth, Gloucestershire (aged...
# 872                                                    -
# 935                                                    -
# Name: Died, dtype: object

# %%
df["Born"].head(20)
# Out:
# 23                 \nNovember 28, 1991, Pakistan
# 30                            \nOctober 18, 1988
# 34      \nApril 22, 1937, Falkirk, Stirlingshire
# 41      \nJuly 22, 1979, Karachi, Sind, Pakistan
# 218                           \nOctober 24, 1987
# 332                               \ndate unknown
# 334                           \nOctober 30, 1985
# 335                          \nDecember 12, 1995
# 336                              \nJuly 22, 2000
# 337                               \ndate unknown
# 338                          \nDecember 26, 1998
# 347                 \nOctober 10, 1987, Pakistan
# 493                 \nDecember 26, 1996, Chakwal
# 523                 \nSeptember 30, 1962, Lahore
# 627           \nDecember 20, 1989, Karachi, Sind
# 676    \nSeptember 6, 1995, Jalgaon, Maharashtra
# 688                               \ndate unknown
# 722           \nMay 8, 1802, Westminster, London
# 872     \nJuly 8, 2001, Birmingham, Warwickshire
# 935                               \ndate unknown
# Name: Born, dtype: object

# %%
df["Born"].tail(20)
# Out:
# 89791                                      \ndate unknown
# 89812               \nOctober 10, 2000, Trinidad & Tobago
# 89856                         \nDecember 2, 1998, Jamaica
# 89886                         \nJanuary 30, 1966, Jamaica
# 89952                            \nJune 15, 1962, Grenada
# 89955           \nNovember 5, 1961, Sandy Point, St Kitts
# 89982    \nSeptember 23, 1983, New Amsterdam, West Bank...
# 90056                                      \ndate unknown
# 90067                                      \ndate unknown
# 90086                           \nMarch 28, 2000, Antigua
# 90098                                      \ndate unknown
# 90100               \nOctober 22, 1962, Trinidad & Tobago
# 90127                                      \ndate unknown
# 90146                          \nMarch 16, 1989, Barbados
# 90173                                      \ndate unknown
# 90231                       \nSeptember 1, 1989, Barbados
# 90233               \nJuly 3, 1997, Five Rivers, Trinidad
# 90245                                      \ndate unknown
# 90285                                      \ndate unknown
# 90294                                      \ndate unknown
# Name: Born, dtype: object

# %%
from dateutil.parser import parse

#for val in df["Born"].drop_duplicates():
#    print(val)

df["Born"] = df["Born"].apply(lambda x: '{dd}-{mm}-{yyyy}'.format(dd=parse(x, fuzzy=True).day, mm=parse(x, fuzzy=True).month, yyyy=parse(x, fuzzy=True).year if not x in ['\ndate unknown', '-', 'date unknown'] else x))
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-152-36367d2a0736> in <module>
#       4 #    print(val)
#       5
# ----> 6 df["Born"] = df["Born"].apply(lambda x: '{dd}-{mm}-{yyyy}'.format(dd=parse(x, fuzzy=True).day, mm=parse(x, fuzzy=True).month, yyyy=parse(x, fuzzy=True).year if not x in ['\ndate unknown', '-', 'date unknown'] else x))
#
# ~/.local/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-152-36367d2a0736> in <lambda>(x)
#       4 #    print(val)
#       5
# ----> 6 df["Born"] = df["Born"].apply(lambda x: '{dd}-{mm}-{yyyy}'.format(dd=parse(x, fuzzy=True).day, mm=parse(x, fuzzy=True).month, yyyy=parse(x, fuzzy=True).year if not x in ['\ndate unknown', '-', 'date unknown'] else x))
#
# ~/.local/lib/python3.7/site-packages/dateutil/parser/_parser.py in parse(timestr, parserinfo, **kwargs)
#    1372         return parser(parserinfo).parse(timestr, **kwargs)
#    1373     else:
# -> 1374         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1375
#    1376
#
# ~/.local/lib/python3.7/site-packages/dateutil/parser/_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     650
#     651         if len(res) == 0:
# --> 652             raise ParserError("String does not contain a date: %s", timestr)
#     653
#     654         try:
#
# ParserError: String does not contain a date:
# date unknown

# %%
import numpy as np

df[["BATTING_Tests_Runs",
    "BATTING_Tests_BF",
    "BATTING_Tests_SR",
    "BATTING_Tests_100",
    "BATTING_Tests_50",
    "BATTING_Tests_4s",
    "BATTING_Tests_6s",
    "BATTING_ODIs_Runs",
    "BATTING_ODIs_BF",
    "BATTING_ODIs_SR",
    "BATTING_ODIs_100",
    "BATTING_ODIs_50",
    "BATTING_ODIs_4s",
    "BATTING_ODIs_6s",
    "BATTING_T20Is_Runs",
    "BATTING_T20Is_BF",
    "BATTING_T20Is_SR",
    "BATTING_T20Is_100",
    "BATTING_T20Is_50",
    "BATTING_T20Is_4s",
    "BATTING_T20Is_6s",
    "BOWLING_Tests_Balls",
    "BOWLING_Tests_Runs",
    "BOWLING_Tests_Wkts",
    "BOWLING_Tests_Econ",
    "BOWLING_ODIs_Balls",
    "BOWLING_ODIs_Runs",
    "BOWLING_ODIs_Wkts",
    "BOWLING_ODIs_Econ",
    "BOWLING_T20Is_Balls",
    "BOWLING_T20Is_Runs",
    "BOWLING_T20Is_Wkts",
    "BOWLING_T20Is_Econ"]] = df[["BATTING_Tests_Runs",
                                "BATTING_Tests_BF",
                                "BATTING_Tests_SR",
                                "BATTING_Tests_100",
                                "BATTING_Tests_50",
                                "BATTING_Tests_4s",
                                "BATTING_Tests_6s",
                                "BATTING_ODIs_Runs",
                                "BATTING_ODIs_BF",
                                "BATTING_ODIs_SR",
                                "BATTING_ODIs_100",
                                "BATTING_ODIs_50",
                                "BATTING_ODIs_4s",
                                "BATTING_ODIs_6s",
                                "BATTING_T20Is_Runs",
                                "BATTING_T20Is_BF",
                                "BATTING_T20Is_SR",
                                "BATTING_T20Is_100",
                                "BATTING_T20Is_50",
                                "BATTING_T20Is_4s",
                                "BATTING_T20Is_6s",
                                "BOWLING_Tests_Balls",
                                "BOWLING_Tests_Runs",
                                "BOWLING_Tests_Wkts",
                                "BOWLING_Tests_Econ",
                                "BOWLING_ODIs_Balls",
                                "BOWLING_ODIs_Runs",
                                "BOWLING_ODIs_Wkts",
                                "BOWLING_ODIs_Econ",
                                "BOWLING_T20Is_Balls",
                                "BOWLING_T20Is_Runs",
                                "BOWLING_T20Is_Wkts",
                                "BOWLING_T20Is_Econ"]].replace("-", np.nan)


df = df.astype(column_types)

#df[["BATTING_Tests_Runs"]].drop_duplicates().loc[type(df["BATTING_Tests_Runs"]) == "str"]

# %%
test_df = df[["NAME", "Major teams"]].groupby(["NAME"]).count()
test_df = test_df.loc[test_df["Major teams"] > 1]
test_df.index

people = list(test_df.index)
people
# Out:
# ['Aimee Maria',
#  'Alan Spiers',
#  'David Brown',
#  'David Simpson',
#  'Greg Francois',
#  'Harold Sheppard',
#  'James Graham',
#  'James Jones',
#  'James Mitchell',
#  'Kapila Perera',
#  'Michael Williams',
#  'Mohammad Asif',
#  'Munir Khan',
#  'Peter Thompson',
#  'Riswan Farouq',
#  'Robert Wilson',
#  'Ross Mitchinson',
#  'Russell Emmins',
#  'Ryan Watson']

# %%
df[["NAME", "Born", "Major teams", "BOWLING_ODIs_Balls", "BOWLING_ODIs_Econ", "BATTING_ODIs_Runs", "BATTING_ODIs_BF"]].loc[df["NAME"].isin(people)]
# Out:
#                    NAME                                               Born  \
# 9597      Mohammad Asif              \nJanuary 1, 1970, Karachi, Pakistan
# 10700  Michael Williams                     \nSeptember 14, 1910, Ireland
# 10777       David Brown             \nJune 14, 1941, Insch, Aberdeenshire
# 10778       David Brown            \nDecember 24, 1849, Dunfermline, Fife
# 10779       David Brown                \nJuly 29, 1900, Dunfermline, Fife
# 10943      James Graham                           \nNovember 2, 1874, Ayr
# 11011       James Jones         \nJanuary 9, 1911, Larbert, Stirlingshire
# 11012       James Jones         \nAugust 19, 1910, Larbert, Stirlingshire
# 11079   Ross Mitchinson             \nApril 14, 1978, Kirkaldy, Fifeshire
# 11080   Ross Mitchinson                        \nApril 14, 1978, Scotland
# 11246       Alan Spiers                                \nJanuary 26, 1979
# 11247       Alan Spiers                      \nJanuary 26, 1979, Scotland
# 11272     David Simpson             \nFebruary 23, 1961, Irvine, Ayrshire
# 11277   Harold Sheppard                 \nMay 20, 1889, Pewsey, Wiltshire
# 11280   Harold Sheppard        \nSeptember 11, 1917, Glasgow, Lanarkshire
# 11302    Peter Thompson                        \nFebruary 19, 1862, Banff
# 11303    Peter Thompson              \nFebruary 19, 1862, Banff, Scotland
# 11326     Robert Wilson        \nFebruary 12, 1935, Paisley, Renfrewshire
# 11327     Robert Wilson            \nApril 8, 1916, Edinburgh, Midlothian
# 11353       Ryan Watson  \nNovember 12, 1976, Salisbury (now Harare), R...
# 13843        Munir Khan                      \nNovember 19, 1956, Nairobi
# 13896       Aimee Maria                                    \ndate unknown
# 13897       Aimee Maria                                    \ndate unknown
# 17763      James Graham              \nAugust 11, 1906, Rathmines, Dublin
# 17958    James Mitchell  \nOctober 19, 1946, Cullion, Dunamanagh, Co Ty...
# 17959    James Mitchell                        \nOctober 3, 1996, Ireland
# 18201     David Simpson                      \nJuly 20, 1983, Londonderry
# 18372        Munir Khan                                    \ndate unknown
# 18447     Riswan Farouq                                    \ndate unknown
# 21202     Riswan Farouq                        \ndate unknown, Bangladesh
# 27425       Ryan Watson                              \nSeptember 29, 1994
# 44478     Mohammad Asif                                \nNovember 1, 1999
# 50031     Kapila Perera                                    \ndate unknown
# 51287     Kapila Perera                                    \ndate unknown
# 72315    Russell Emmins                        \nJuly 14, 1962, Australia
# 72316    Russell Emmins                                    \ndate unknown
# 87064  Michael Williams                                    \ndate unknown
# 88395     Greg Francois      \nMarch 11, 1981, Toucarie Village, Dominica
# 88396     Greg Francois      \nMarch 11, 1981, Toucarie Village, Dominica
#
#                   Major teams  BOWLING_ODIs_Balls  BOWLING_ODIs_Econ  \
# 9597                     Oman                 NaN                NaN
# 10700                 Ireland                 NaN                NaN
# 10777                Scotland                 NaN                NaN
# 10778                Scotland                 NaN                NaN
# 10779                Scotland                 NaN                NaN
# 10943                Scotland                 NaN                NaN
# 11011                Scotland                 NaN                NaN
# 11012                Scotland                 NaN                NaN
# 11079      Scotland Under-19s                 NaN                NaN
# 11080      Scotland Under-19s                 NaN                NaN
# 11246      Scotland Under-19s                 NaN                NaN
# 11247      Scotland Under-19s                 NaN                NaN
# 11272                Scotland                 NaN                NaN
# 11277                Scotland                 NaN                NaN
# 11280                Scotland                 NaN                NaN
# 11302                Scotland                 NaN                NaN
# 11303                Scotland                 NaN                NaN
# 11326                Scotland                 NaN                NaN
# 11327                Scotland                 NaN                NaN
# 11353                Scotland               570.0               5.55
# 13843                   Kenya                 NaN                NaN
# 13896             Kenya Women                 NaN                NaN
# 13897             Kenya Women                 NaN                NaN
# 17763                 Ireland                 NaN                NaN
# 17958                 Ireland                 NaN                NaN
# 17959       Ireland Under-19s                 NaN                NaN
# 18201                 Ireland                 NaN                NaN
# 18372     Hong Kong Under-19s                 NaN                NaN
# 18447               Hong Kong                 NaN                NaN
# 21202               Hong Kong                 NaN                NaN
# 27425   New Zealand Under-19s                 NaN                NaN
# 44478      Pakistan Under-19s                 NaN                NaN
# 50031     Sri Lanka Under-19s                 NaN                NaN
# 51287     Sri Lanka Under-19s                 NaN                NaN
# 72315     Australia Under-19s                 NaN                NaN
# 72316     Australia Under-19s                 NaN                NaN
# 87064  South Africa Under-19s                 NaN                NaN
# 88395   West Indies Under-19s                 NaN                NaN
# 88396             West Indies                 NaN                NaN
#
#        BATTING_ODIs_Runs  BATTING_ODIs_BF
# 9597                 NaN              NaN
# 10700                NaN              NaN
# 10777                NaN              NaN
# 10778                NaN              NaN
# 10779                NaN              NaN
# 10943                NaN              NaN
# 11011                NaN              NaN
# 11012                NaN              NaN
# 11079                NaN              NaN
# 11080                NaN              NaN
# 11246                NaN              NaN
# 11247                NaN              NaN
# 11272                NaN              NaN
# 11277                NaN              NaN
# 11280                NaN              NaN
# 11302                NaN              NaN
# 11303                NaN              NaN
# 11326                NaN              NaN
# 11327                NaN              NaN
# 11353              956.0           1286.0
# 13843                NaN              NaN
# 13896                NaN              NaN
# 13897                NaN              NaN
# 17763                NaN              NaN
# 17958                NaN              NaN
# 17959                NaN              NaN
# 18201                NaN              NaN
# 18372                NaN              NaN
# 18447                NaN              NaN
# 21202                NaN              NaN
# 27425                NaN              NaN
# 44478                NaN              NaN
# 50031                NaN              NaN
# 51287                NaN              NaN
# 72315                NaN              NaN
# 72316                NaN              NaN
# 87064                NaN              NaN
# 88395                NaN              NaN
# 88396                NaN              NaN

# %% [markdown]
# The dataset has some identical sets of player names, who may or may not correspond to the same person (as is evident from the values of the "Born" and "Major teams" fields). This would have required appending an extra indicator (year of birth, team name) at the end of these player's names in order to be able to distinguish them.
#
# However, all these players (except for one) seem to have missing values in all batting and bowling stats columns, so the rows with identical names will anyway get eliminated once the dropna() function is applied to the dataframe to get rid of entries that do not have the required details.
# Hence, no extra logic will be applied in trying to distinguish these names.

# %%
df["sport"] = "Cricket"

# %%
df.groupby(["NAME", "Major teams"])
